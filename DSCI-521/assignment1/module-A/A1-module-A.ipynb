# %% [markdown]
# ## Module submission header
# ### Submission preparation instructions
# _Completion of this header is mandatory, subject to a 2-point deduction to the assignment._ Only add plain text in the designated areas, i.e., replacing the relevant 'NA's. You must fill out all group member Names and Drexel email addresses in the below markdown list, under header __Module submission group__. It is required to fill out descriptive notes pertaining to any tutoring support received in the completion of this submission under the __Additional submission comments__ section at the bottom of the header. If no tutoring support was received, leave NA in place. You may as well list other optional comments pertaining to the submission at bottom. _Any distruption of this header's formatting will make your group liable to the 2-point deduction._
#
# ### Module submission group
# - Group member 1
#     - Name: NA
#     - Email: NA
# - Group member 2
#     - Name: NA
#     - Email: NA
# - Group member 3
#     - Name: NA
#     - Email: NA
# - Group member 4
#     - Name: NA
#     - Email: NA
#
# ### Additional submission comments
# - Tutoring support received: NA
# - Other (other): NA

# %% [markdown]
# # Assignment group 1: Textual feature extraction and numerical comparison

# %% [markdown]
# ## Module A _(35 points)_ Processing numeric data

# %% [markdown]
# In this module, you will be working with the demographics data from The Henry J. Kaiser Family Foundation (https://www.kff.org/) including the population of 52 locations (50 states, District of Columbia, and Puerto Rico) based on race, gender, age, and the number of adults with and without children. This data is obtained from the Census Bureau’s American Community Survey (ACS). The data is stored in a `csv` file format located in the attached `data` directory.

# %% [markdown]
# __A1.__ Write a function called `get_shape_and_column` that accepts a string representing the path to the demographics.csv data. This function should read the provided csv data file into a pandas dataframe and then return a tuple with three things: the data frame (`data`), the shape of the data frame (`shape`), and a list of the columns (`columns`). (3 points)

# %%
# A1:Function(3/3)
# get_shape_and_column('./data/demographics.csv'):data,shape,column

import pandas as pd

def get_shape_and_columns(csv_path):
    
    #---Your code starts here---
    data =pd.read_csv(csv_path)
    shape = data.shape
    columns = data.columns
    #---Your code ends here---
    return data, shape, columns

# %% [markdown]
# __A2.__ _(2 points)_ To gain a better insight into the data, lets apply the function we just wrote to get our dataframe, inspect the shape and columns, and then look at the head and tail of this data (using the `.head()` and `.tail()` methods).

# %%
# A2:SanityCheck

# Load the data using our function
data, shape, columns = get_shape_and_columns('./data/demographics.csv')

# Output the shape and column names
print(shape)
print(columns)
# Out:
# (52, 18)
# Index(['Location', 'Male', 'Female', 'Adults_with_Children',
#        'Adults_with_No_Children', 'White', 'Black', 'Hispanic', 'Asian',
#        'American_Indian_or_Alaska_Native',
#        'Native_Hawaiian_or_Other_Pacific_Islander', 'Two_Or_More_Races',
#        'Age0_18', 'Age_19_25', 'Age_26_34', 'Age_35_54', 'Age_55_64',
#        'Age_65_plus'],
#       dtype='object')

# %%
# A2:SanityCheck

# Outputs the head of the data
data.head()
# Out:
#      Location      Male    Female  Adults_with_Children  \
# 0     Alabama   2284900   2456500                878300
# 1      Alaska    364500    345600                153600
# 2     Arizona   3363200   3478100               1322700
# 3    Arkansas   1422700   1487200                602000
# 4  California  19113000  19600800               7955200
#
#    Adults_with_No_Children     White      Black  Hispanic      Asian  \
# 0                  1941300   3119100  1259900.0    195700    63800.0
# 1                   283800    433000    18000.0     47400    46600.0
# 2                  2646700   3761600   270200.0   2143400   220300.0
# 3                  1096800   2109200   434100.0    220300    48100.0
# 4                 15981800  14305700  2061600.0  15194400  5598000.0
#
#    American_Indian_or_Alaska_Native  \
# 0                           19800.0
# 1                           95500.0
# 2                          261300.0
# 3                           13500.0
# 4                          138100.0
#
#    Native_Hawaiian_or_Other_Pacific_Islander  Two_Or_More_Races  Age0_18  \
# 0                                        NaN            81800.0  1138300
# 1                                     6300.0            63300.0   192300
# 2                                    12500.0           172000.0  1686200
# 3                                     7300.0            77500.0   730600
# 4                                   122900.0          1293200.0  9363800
#
#    Age_19_25  Age_26_34  Age_35_54  Age_55_64  Age_65_plus
# 0     430500   536200.0    1207200     645600       783600
# 1      63500    97900.0     183600      92400        80500
# 2     637200   815200.0    1677000     839900      1185700
# 3     265200   329800.0     726600     377100       480600
# 4    3697900  5240600.0   10277900    4720500      5413200

# %%
# A2:Inline(1/2)

# Which state is listed first in the head? Print the state name
# from this list of choices: (Alabama, Alaska, Arizona)

print("Alabama")
# Out:
# Alabama

# %%
# A2:SanityCheck

# Outputs the tail of the data
data.tail()
# Out:
#          Location     Male   Female  Adults_with_Children  \
# 47     Washington  3589700  3650100               1522400
# 48  West Virginia   863400   898700                322100
# 49      Wisconsin  2792400  2850600               1161900
# 50        Wyoming   286600   276700                118200
# 51    Puerto Rico  1570300  1734500                543200
#
#     Adults_with_No_Children    White     Black  Hispanic     Asian  \
# 47                  2920700  4976100  246900.0    916000  617900.0
# 48                   714100  1631600   64300.0     20400   14200.0
# 49                  2230900  4600500  328100.0    382000  166800.0
# 50                   214300   474400    5300.0     56100    4200.0
# 51                  1406500    23000       NaN   3274500       NaN
#
#     American_Indian_or_Alaska_Native  \
# 47                           68600.0
# 48                            2000.0
# 49                           43500.0
# 50                           12100.0
# 51                               NaN
#
#     Native_Hawaiian_or_Other_Pacific_Islander  Two_Or_More_Races  Age0_18  \
# 47                                    42200.0           372200.0  1701700
# 48                                        NaN            28800.0   385000
# 49                                        NaN           120600.0  1319600
# 50                                        NaN            11200.0   142400
# 51                                        NaN                NaN   701800
#
#     Age_19_25  Age_26_34  Age_35_54  Age_55_64  Age_65_plus
# 47     628700   965900.0    1899400     949100      1095000
# 48     148600   178300.0     448700     260600       340900
# 49     495600   643300.0    1441400     812500       930500
# 50      48500    69400.0     133100      81500        88300
# 51     327600   344300.0     849600     428200       653200

# %%
# A2:Inline(1/2)

# Which state is listed first in the tail? Print the state name
# from this list of choices: (Wyoming, Puerto Rico, Washington)
print("Washington")
# Out:
# Washington

# %% [markdown]
# __A3.__ _(5 points)_ As you can see, there is no `total` population column in this dataframe for each location. Therefore, let's write a function called `total_columns` that takes a dataframe and two column names and returns an updated dataframe. This function should create a new column in the provided dataframe called `total` that is the sum of the data in the two provided columns. It should return this updated data frame.

# %%
# A3:Function(3/5)
# total_columns('./data/demographics.csv', "Male", "Female")

def total_columns(data, column1, column2):
    #---Your code starts here---
    data['total'] = data[column1] + data[column2]
    #---Your code ends here---
    
    return data

# %% [markdown]
# To test your function, let's apply it to create totals for some of the fields and inspect at the results.
#
# The pandas package provides a `.describe()` method which gives a descriptive summary of the desired column(s) (such as mean, standard deviation, min, and max values). The following code cells print these statistics for the newly created `total` columns.

# %%
# A3:SanityCheck

# Creates a total column for ages 35-64
data = total_columns(data, "Age_35_54", "Age_55_64")

# Uses the describe method to show the summary statistics for the newly created 'total' column
data[['total']].describe()
# Out:
#               total
# count  5.200000e+01
# mean   2.408640e+06
# std    2.750352e+06
# min    2.146000e+05
# 25%    6.786000e+05
# 50%    1.652950e+06
# 75%    2.727825e+06
# max    1.499840e+07

# %%
# A3:SanityCheck

# Creates a total column for ages 19-34
data = total_columns(data, "Age_19_25", "Age_26_34")

# Uses the describe method to show the summary statistics for the newly created 'total' column
data[['total']].describe()
# Out:
#               total
# count  5.200000e+01
# mean   1.309954e+06
# std    1.584595e+06
# min    1.179000e+05
# 25%    3.369500e+05
# 50%    8.690500e+05
# 75%    1.487950e+06
# max    8.938500e+06

# %%
# A3:Inline(2/5)

# Which mean total is greater, the sum of Age_35_54 + Age_55_64 or the sum of Age_19_25 + Age_26_34?
# Print either "Older" or "Younger"

print("Older")
# Out:
# Older

# %% [markdown]
# __A4:__ _(5 points)_ Next, write a function that takes a dataframe that has a `total` column and returns a tuple with four values: the location with the minimum total (`min_location`), the total for that min location (`min_total`), the location with the maximum total (`max_location`), and the total for the max location (`max_total`). Note that the locations returned should correspond to specific states (e.g., `"Alabama"`) and the totals should be numbers (e.g., `23000`)

# %%
# A4:Function(4/5)

def get_min_max_locations(data):
    #---Your code starts here---
    min_total = data['total'].min()
    max_total = data['total'].max()
    min_location = data[data['total'] == min_total]['Location'].values[0]
    max_location = data[data['total'] == max_total]['Location'].values[0]
    #---Your code ends here---
    return min_location, min_total, max_location, max_total

# %% [markdown]
# Let's apply the functions you have created to (1) total up the male and female population counts and (2) identify the states with the minimum and maximum totals and their total amounts.

# %%
# A4:SanityCheck

# Create a total column that contains Male + Female
data = total_columns(data, "Male", "Female")

# Get the min and max states
min_loc, min_total, max_loc, max_total = get_min_max_locations(data)

print("Minimum location: {} (total={})".format(min_loc, min_total))
print("Maximum location: {} (total={})".format(max_loc, max_total))
# Out:
# Minimum location: Wyoming (total=563300)
# Maximum location: California (total=38713800)

# %%
# A4:Inline(1/5)

# Print the state with the smallest total (make sure to get capitalization right)?
print("Wyoming")
# Out:
# Wyoming

# %% [markdown]
# __A5.__ _(5 points)_ Our previous `total_columns` function has some limitations. First, it only lets us create a total column that is the sum of two columns. Additionally, it always names the resulting column `total`. Please write an updated `total_columns` function that takes three arguments: `data` (a dataframe), `list_of_columns` (a list of columns to total), and `total_name` (a name for the resulting total column). This function should total the values across all the columns in `list_of_columns` and put the result in the target `total_name` column.

# %%
# A5:Function(4/5)
def total_columns(data, list_of_columns, total_name="total"):
    #---Your code starts here---
    data[total_name] = data[list_of_columns].sum(axis=1)
    #---Your code ends here---
    return data

# %% [markdown]
# To test the function you've created, let's apply it to investigate our data. In particular, let's look at two columns `Adults_with_Children` and `Adults_with_No_Children`. It seems that the populations in these two columns do not include the children (aged younger than 18 years), and older adults (aged older than 64 years). To confirm this hypothesis, let's use our new `total_columns` function to create two total columns and then compare them. We will then look to see if there is a difference between these totals for three states: `Pennsylvania`, `Colorado`, and `Georgia`.

# %%
# A5:SanityCheck

# Create a total for all the adult age groups (excluding people youger than 18 or older than 64)
adult_age_group_columns = ['Age_19_25', 'Age_26_34', 'Age_35_54', 'Age_55_64']
data = total_columns(data, adult_age_group_columns, "total_adult_age_groups")

# Create a total column for adults with and without children.
adults_columns = ['Adults_with_Children', 'Adults_with_No_Children']
data = total_columns(data, adults_columns, "total_adults")

# Compute the difference between these values
data['diff'] = data['total_adult_age_groups'] - data['total_adults']

# Look at the differences for Pennsylvania, Colorado, and Georgia
print("Pennsylvania difference: {}".format(data[data['Location'] == "Pennsylvania"]['diff'].values))
print("Colorado difference: {}".format(data[data['Location'] == "Colorado"]['diff'].values))
print("Georgia difference: {}".format(data[data['Location'] == "Georgia"]['diff'].values))
# Out:
# Pennsylvania difference: [0.]
# Colorado difference: [0.]
# Georgia difference: [0.]

# %%
# A5:Inline(1/5)

# Is there a difference for these three states? Print "Yes" or "No"
print("Yes ")
# Out:
# Yes

# %% [markdown]
# __A6:__ _(2 points)_ To investigate our hypothesis more generally, write a function called `are_columns_equal` that takes a dataframe and two columns names (for two columns we want to compare). The function should return a boolean value `are_equal` that is True if all the values for the two columns are the same and False if there is at least one difference.

# %%
# A6:Function(2/2)

def are_columns_equal(data, column1, column2):
    #---Your code starts here---
    are_equal = data[column1].equals(data[column2])
    #---Your code starts here---
    
    return are_equal

# %% [markdown]
# To test this function, let's apply it to test our hypothesis that`total_adult_age_groups` and `total_adults` are the same for all locations.

# %%
# A6:SanityCheck

print(are_columns_equal(data, 'total_adult_age_groups', 'total_adults'))
# Out:
# False

# %% [markdown]
# __A7:__ _(3 points)_ It seems that our hypothesis is not correct for all the locations. To investigate further, create a function called `get_location_difference_dict` that takes a dataframe and two column names and returns a dictionary (`location_diff_dict`) that has locations for keys and the difference (column1 value - column2 value) as values. Additionally, the dictionary should only include values for entries that have a non-zero difference (places where column1 value != column2 value).
#
# For example, the resulting dictionary should look something like this:
# ```
# {'Alabama': 300,
#  'California': -210,
#  ...
# }
# ```

# %%
# A7:Function(2/3)

def get_location_difference_dict(data, column1, column2):
    #---Your code starts here---
    location_diff_dict = {}
    for index, row in data.iterrows():
        location_diff_dict[row['Location']] = row[column1] - row[column2]
    #---Your code ends here---
    
    return location_diff_dict

# %% [markdown]
# Now let's apply the function you have created to see what the differences in `total_adult_age_groups` and `total_adults` look like across our data.

# %%
# A7:SanityCheck
get_location_difference_dict(data,'total_adult_age_groups', 'total_adults')
# Out:
# {'Alabama': -100.0,
#  'Alaska': 0.0,
#  'Arizona': -100.0,
#  'Arkansas': -100.0,
#  'California': -100.0,
#  'Colorado': 0.0,
#  'Connecticut': 0.0,
#  'Delaware': -100.0,
#  'District of Columbia': 0.0,
#  'Florida': -100.0,
#  'Georgia': 0.0,
#  'Hawaii': 0.0,
#  'Idaho': 100.0,
#  'Illinois': 100.0,
#  'Indiana': 0.0,
#  'Iowa': 100.0,
#  'Kansas': -100.0,
#  'Kentucky': -100.0,
#  'Louisiana': -100.0,
#  'Maine': 0.0,
#  'Maryland': 0.0,
#  'Massachusetts': 0.0,
#  'Michigan': 0.0,
#  'Minnesota': -100.0,
#  'Mississippi': 0.0,
#  'Missouri': 0.0,
#  'Montana': 100.0,
#  'Nebraska': -100.0,
#  'Nevada': 0.0,
#  'New Hampshire': 0.0,
#  'New Jersey': 0.0,
#  'New Mexico': 100.0,
#  'New York': 0.0,
#  'North Carolina': -200.0,
#  'North Dakota': -100.0,
#  'Ohio': 0.0,
#  'Oklahoma': 100.0,
#  'Oregon': 100.0,
#  'Pennsylvania': 0.0,
#  'Rhode Island': 0.0,
#  'South Carolina': -100.0,
#  'South Dakota': 0.0,
#  'Tennessee': 0.0,
#  'Texas': 0.0,
#  'Utah': -100.0,
#  'Vermont': 100.0,
#  'Virginia': -200.0,
#  'Washington': 0.0,
#  'West Virginia': 0.0,
#  'Wisconsin': 0.0,
#  'Wyoming': 0.0,
#  'Puerto Rico': 0.0}

# %%
x = get_location_difference_dict(data,'total_adult_age_groups', 'total_adults')

# %%
## getting the largest absolute value in the dictionary
max(x, key=lambda k: abs(x[k]))
# Out:
# 'North Carolina'

# %%
# A7:Inline(1/3)

# Print the name of the state with the larger difference (greater absolute magnitude),
# "Alabama" or "North Carolina"?
print("North Carolina")
# Out:
# North Carolina

# %% [markdown]
# __A8.__ _(7 points)_ In this problem, we are going to investigate the similarity of locations using _cosine similarity_. To support these investigations, write a function called `compute_cosine_similarity` that takes a dataframe (`data`) and a list of column names (`similarity_columns`) to use when computing the cosine similarity. This function should use the provided `similarity_columns` to compute the cosine similiarity between each pair of locations. In cases where there is no population for one of the provided columns for a location in the dataframe (the corresponding value is `NaN`), replace them with `zero` using the `.fillna()` method of pandas. This function should return a list of tuples (`similarity_list`) with the following format `(<location 1>, <location 2>, <cosine similarity between them>)`.
#
# Here is an example of what the output from this function should look like:
# ```
# [('Alabama', 'Alaska', 0.223890893223),
#  ('Alabama', 'Arizona', 0.43432273237),
#  ('Alabama', 'Arkansas', 0.112312121213),
#  ('Alabama', 'California', 0.45645645654623),
#  ('Alabama', 'Colorado', 0.234616734),
#  ('Alabama', 'Connecticut', 0.676533422),
#  ('Alabama', 'Delaware', 0.1234645667),
#  ...
# ]
# ```
#
# Note that each pair of locations will appear twice in this list in different orders; e.g., `('Alabama', 'Alaska', 223890893223)` and `('Alaska', 'Alabama', 223890893223)` will both appear.

# %%
# A8:Function(7/7)
import numpy as np

def compute_cosine_similarity(data, similarity_columns):
    #---Your code starts here
    similarity_list = []
    for index1, row1 in data.iterrows():
        for index2, row2 in data.iterrows():
            if index1 < index2:
                vector1 = row1[similarity_columns].fillna(0).values
                vector2 = row2[similarity_columns].fillna(0).values
                similarity = np.dot(vector1, vector2) / (np.linalg.norm(vector1) * np.linalg.norm(vector2))
                similarity_list.append((row1['Location'], row2['Location'], similarity))
    #---Your code ends here

    return similarity_list

# %% [markdown]
# To test our function, lets apply it to compare locations according to both race and age demographics.

# %%
# A8:SanityCheck

# All the race columns
race_columns = ['White', 'Black', 'Hispanic', 'Asian', 'American_Indian_or_Alaska_Native', \
                'Native_Hawaiian_or_Other_Pacific_Islander', 'Two_Or_More_Races']

race_similarity = compute_cosine_similarity(data, race_columns)
race_similarity
# Out:
# [('Alabama', 'Alaska', 0.9114268387800772),
#  ('Alabama', 'Arizona', 0.8532153881652852),
#  ('Alabama', 'Arkansas', 0.982778111554958),
#  ('Alabama', 'California', 0.6910373396673632),
#  ('Alabama', 'Colorado', 0.9181663981509594),
#  ('Alabama', 'Connecticut', 0.9553103684194725),
#  ('Alabama', 'Delaware', 0.9942087439512888),
#  ('Alabama', 'District of Columbia', 0.8600337602418917),
#  ('Alabama', 'Florida', 0.9251438820043797),
#  ('Alabama', 'Georgia', 0.983733285870616),
#  ('Alabama', 'Hawaii', 0.4266773857139479),
#  ('Alabama', 'Idaho', 0.9265581661297341),
#  ('Alabama', 'Illinois', 0.9626915658026344),
#  ('Alabama', 'Indiana', 0.963493028315945),
#  ('Alabama', 'Iowa', 0.9400898150890012),
#  ('Alabama', 'Kansas', 0.9466816358199139),
#  ('Alabama', 'Kentucky', 0.9578361229344373),
#  ('Alabama', 'Louisiana', 0.9935406238636664),
#  ('Alabama', 'Maine', 0.9309310956689741),
#  ('Alabama', 'Maryland', 0.9797117035348595),
#  ('Alabama', 'Massachusetts', 0.9518043913154132),
#  ('Alabama', 'Michigan', 0.9786086627973689),
#  ('Alabama', 'Minnesota', 0.9533492410853135),
#  ('Alabama', 'Mississippi', 0.9797211311228103),
#  ('Alabama', 'Missouri', 0.9701309473076928),
#  ('Alabama', 'Montana', 0.9272791022393161),
#  ('Alabama', 'Nebraska', 0.9437434232864612),
#  ('Alabama', 'Nevada', 0.8665517040566361),
#  ('Alabama', 'New Hampshire', 0.9325767465198712),
#  ('Alabama', 'New Jersey', 0.9363323061112477),
#  ('Alabama', 'New Mexico', 0.6112561934145454),
#  ('Alabama', 'New York', 0.9485103781821569),
#  ('Alabama', 'North Carolina', 0.9942625373381712),
#  ('Alabama', 'North Dakota', 0.9378994924660654),
#  ('Alabama', 'Ohio', 0.972775980972594),
#  ('Alabama', 'Oklahoma', 0.9487459697176487),
#  ('Alabama', 'Oregon', 0.9294367794312076),
#  ('Alabama', 'Pennsylvania', 0.9685677854168596),
#  ('Alabama', 'Rhode Island', 0.9415911457346866),
#  ('Alabama', 'South Carolina', 0.9996860508015731),
#  ('Alabama', 'South Dakota', 0.9322526150805064),
#  ('Alabama', 'Tennessee', 0.986286158338955),
#  ('Alabama', 'Texas', 0.7706192116570828),
#  ('Alabama', 'Utah', 0.9264901099318691),
#  ('Alabama', 'Vermont', 0.9312179809756669),
#  ('Alabama', 'Virginia', 0.9884637935743699),
#  ('Alabama', 'Washington', 0.9321877685418578),
#  ('Alabama', 'West Virginia', 0.940263104059358),
#  ('Alabama', 'Wisconsin', 0.9513751984833456),
#  ('Alabama', 'Wyoming', 0.9299937398958478),
#  ('Alabama', 'Puerto Rico', 0.06454597923355133),
#  ('Alaska', 'Arizona', 0.9026314648157775),
#  ('Alaska', 'Arkansas', 0.9573184971397108),
#  ('Alaska', 'California', 0.7416111800267029),
#  ('Alaska', 'Colorado', 0.9529090361921406),
#  ('Alaska', 'Connecticut', 0.9590604204992826),
#  ('Alaska', 'Delaware', 0.9324782076163214),
#  ('Alaska', 'District of Columbia', 0.6413542327967735),
#  ('Alaska', 'Florida', 0.8979329300291786),
#  ('Alaska', 'Georgia', 0.8608148284067335),
#  ('Alaska', 'Hawaii', 0.5558277164519617),
#  ('Alaska', 'Idaho', 0.9684398619035819),
#  ('Alaska', 'Illinois', 0.9445909976721486),
#  ('Alaska', 'Indiana', 0.9656589790206699),
#  ('Alaska', 'Iowa', 0.9674995406230946),
#  ('Alaska', 'Kansas', 0.9700735806335807),
#  ('Alaska', 'Kentucky', 0.9635735162271176),
#  ('Alaska', 'Louisiana', 0.8722983370552183),
#  ('Alaska', 'Maine', 0.962625673192613),
#  ('Alaska', 'Maryland', 0.8661491682809547),
#  ('Alaska', 'Massachusetts', 0.9696407140106729),
#  ('Alaska', 'Michigan', 0.9609130145755891),
#  ('Alaska', 'Minnesota', 0.9710544469699891),
#  ('Alaska', 'Mississippi', 0.8269624058659124),
#  ('Alaska', 'Missouri', 0.9630283412373561),
#  ('Alaska', 'Montana', 0.9760433744460008),
#  ('Alaska', 'Nebraska', 0.9694013614500698),
#  ('Alaska', 'Nevada', 0.8874290078701618),
#  ('Alaska', 'New Hampshire', 0.9644770916340348),
#  ('Alaska', 'New Jersey', 0.9286428631991214),
#  ('Alaska', 'New Mexico', 0.6920083261789891),
#  ('Alaska', 'New York', 0.9303033650880927),
#  ('Alaska', 'North Carolina', 0.9361053969669316),
#  ('Alaska', 'North Dakota', 0.9758136264149295),
#  ('Alaska', 'Ohio', 0.9615100295026751),
#  ('Alaska', 'Oklahoma', 0.9881780339860428),
#  ('Alaska', 'Oregon', 0.9724164260957551),
#  ('Alaska', 'Pennsylvania', 0.9647942327380913),
#  ('Alaska', 'Rhode Island', 0.9657418847842117),
#  ('Alaska', 'South Carolina', 0.908969396965082),
#  ('Alaska', 'South Dakota', 0.9808748234590109),
#  ('Alaska', 'Tennessee', 0.9524987790341366),
#  ('Alaska', 'Texas', 0.7690879670609413),
#  ('Alaska', 'Utah', 0.9680797021853658),
#  ('Alaska', 'Vermont', 0.9621189617047786),
#  ('Alaska', 'Virginia', 0.9445102159522079),
#  ('Alaska', 'Washington', 0.9751679121530703),
#  ('Alaska', 'West Virginia', 0.960893537901065),
#  ('Alaska', 'Wisconsin', 0.9695107220586875),
#  ('Alaska', 'Wyoming', 0.9703627448103928),
#  ('Alaska', 'Puerto Rico', 0.11129559767852998),
#  ('Arizona', 'Arkansas', 0.9063079846094056),
#  ('Arizona', 'California', 0.9338928225441736),
#  ('Arizona', 'Colorado', 0.9764531765527141),
#  ('Arizona', 'Connecticut', 0.9574003581046278),
#  ('Arizona', 'Delaware', 0.9001647385340033),
#  ('Arizona', 'District of Columbia', 0.6662098831475625),
#  ('Arizona', 'Florida', 0.978898793892221),
#  ('Arizona', 'Georgia', 0.8464482639610496),
#  ('Arizona', 'Hawaii', 0.5143013674974541),
#  ('Arizona', 'Idaho', 0.9299215337817671),
#  ('Arizona', 'Illinois', 0.9585851918151176),
#  ('Arizona', 'Indiana', 0.9065467877276007),
#  ('Arizona', 'Iowa', 0.8992966657628899),
#  ('Arizona', 'Kansas', 0.934060447204825),
#  ('Arizona', 'Kentucky', 0.8865595843085383),
#  ('Arizona', 'Louisiana', 0.827054394402121),
#  ('Arizona', 'Maine', 0.874224624168672),
#  ('Arizona', 'Maryland', 0.8539487063405387),
#  ('Arizona', 'Massachusetts', 0.9360179893894452),
#  ('Arizona', 'Michigan', 0.894087963404488),
#  ('Arizona', 'Minnesota', 0.8990676993941753),
#  ('Arizona', 'Mississippi', 0.7752124986583766),
#  ('Arizona', 'Missouri', 0.8905241098238862),
#  ('Arizona', 'Montana', 0.8867762061596615),
#  ('Arizona', 'Nebraska', 0.927477769132209),
#  ('Arizona', 'Nevada', 0.9901924342246191),
#  ('Arizona', 'New Hampshire', 0.8853314016831053),
#  ('Arizona', 'New Jersey', 0.9691751298981427),
#  ('Arizona', 'New Mexico', 0.9168164714931539),
#  ('Arizona', 'New York', 0.9631984826307989),
#  ('Arizona', 'North Carolina', 0.9029150567804028),
#  ('Arizona', 'North Dakota', 0.8878080353850674),
#  ('Arizona', 'Ohio', 0.8872259176389972),
#  ('Arizona', 'Oklahoma', 0.933157307600465),
#  ('Arizona', 'Oregon', 0.9386690744217069),
#  ('Arizona', 'Pennsylvania', 0.908907521821336),
#  ('Arizona', 'Rhode Island', 0.9524238904925794),
#  ('Arizona', 'South Carolina', 0.8597014243380098),
#  ('Arizona', 'South Dakota', 0.8884426909932703),
#  ('Arizona', 'Tennessee', 0.8911980187533821),
#  ('Arizona', 'Texas', 0.9608864884780948),
#  ('Arizona', 'Utah', 0.9397720414558244),
#  ('Arizona', 'Vermont', 0.874947951952659),
#  ('Arizona', 'Virginia', 0.9084825331987361),
#  ('Arizona', 'Washington', 0.9408473413271422),
#  ('Arizona', 'West Virginia', 0.872698869021041),
#  ('Arizona', 'Wisconsin', 0.9061819715638704),
#  ('Arizona', 'Wyoming', 0.918569296300642),
#  ('Arizona', 'Puerto Rico', 0.4982595935263127),
#  ('Arkansas', 'California', 0.7384153531926174),
#  ('Arkansas', 'Colorado', 0.9687218582307586),
#  ('Arkansas', 'Connecticut', 0.9883751639872266),
#  ('Arkansas', 'Delaware', 0.9910222160736963),
#  ('Arkansas', 'District of Columbia', 0.7644289946625467),
#  ('Arkansas', 'Florida', 0.9437253538832346),
#  ('Arkansas', 'Georgia', 0.9459555438010858),
#  ('Arkansas', 'Hawaii', 0.4597658668196641),
#  ('California', 'Michigan', 0.7201047651406552),
#  ('California', 'Minnesota', 0.723148437120734),
#  ('California', 'Mississippi', 0.6329849227581771),
#  ('California', 'Missouri', 0.7078445448224978),
#  ('California', 'Montana', 0.6888932657991129),
#  ('California', 'Nebraska', 0.7607050564869297),
#  ('California', 'Nevada', 0.9549996640451381),
#  ('California', 'New Hampshire', 0.6949942990933046),
#  ('California', 'New Jersey', 0.8934553972136937),
#  ('California', 'New Mexico', 0.9538425520938494),
#  ('California', 'New York', 0.8798198493008991),
#  ('California', 'North Carolina', 0.7574179328077948),
#  ('California', 'North Dakota', 0.6930189251487827),
#  ('California', 'Ohio', 0.7047784580752574),
#  ('California', 'Oklahoma', 0.7711532887580694),
#  ('California', 'Oregon', 0.7844097592698576),
#  ('California', 'Pennsylvania', 0.7394331310115307),
#  ('California', 'Rhode Island', 0.8081276424216156),
#  ('California', 'South Carolina', 0.704290164749389),
#  ('California', 'South Dakota', 0.6919337232969099),
#  ('California', 'Tennessee', 0.7176723761275959),
#  ('California', 'Texas', 0.9771845343042149),
#  ('California', 'Utah', 0.7801180373551587),
#  ('California', 'Vermont', 0.6776705322264622),
#  ('California', 'Virginia', 0.7745151562823558),
#  ('California', 'Washington', 0.8049241214879673),
#  ('California', 'West Virginia', 0.6729696690694444),
#  ('California', 'Wisconsin', 0.7285332165378846),
#  ('California', 'Wyoming', 0.7397690592788428),
#  ('California', 'Puerto Rico', 0.7033780569347892),
#  ('Colorado', 'Connecticut', 0.9937269035418532),
#  ('Colorado', 'Delaware', 0.9512590318430023),
#  ('Colorado', 'District of Columbia', 0.6747252268305808),
#  ('Colorado', 'Florida', 0.9716213602469879),
#  ('Colorado', 'Georgia', 0.8849408361649295),
#  ('Colorado', 'Hawaii', 0.504041160785644),
#  ('Colorado', 'Idaho', 0.9862761393158533),
#  ('Colorado', 'Illinois', 0.9862519777966801),
#  ('Colorado', 'Indiana', 0.9742947042308331),
#  ('Colorado', 'Iowa', 0.9717565136636775),
#  ('Colorado', 'Kansas', 0.9885138706013835),
#  ('Colorado', 'Kentucky', 0.9639158503419016),
#  ('Colorado', 'Louisiana', 0.8830239692092503),
#  ('Colorado', 'Maine', 0.9570773809863938),
#  ('Colorado', 'Maryland', 0.8889747780304846),
#  ('Colorado', 'Massachusetts', 0.9880976588804974),
#  ('Colorado', 'Michigan', 0.9642144088417813),
#  ('Colorado', 'Minnesota', 0.9708426085179555),
#  ('Colorado', 'Mississippi', 0.8338402863495818),
#  ('Colorado', 'Missouri', 0.9644646395867533),
#  ('Colorado', 'Montana', 0.9616363539892523),
#  ('Colorado', 'Nebraska', 0.9857548292027414),
#  ('Colorado', 'Nevada', 0.9645153197296249),
#  ('Colorado', 'New Hampshire', 0.9638569822859498),
#  ('Colorado', 'New Jersey', 0.9796109696027042),
#  ('Colorado', 'New Mexico', 0.8100912742326566),
#  ('Colorado', 'New York', 0.9775921518662355),
#  ('Colorado', 'North Carolina', 0.9532184866691175),
#  ('Colorado', 'North Dakota', 0.9626613193985192),
#  ('Colorado', 'Ohio', 0.9621035280614006),
#  ('Colorado', 'Oklahoma', 0.980453169034812),
#  ('Colorado', 'Oregon', 0.9901733583457137),
#  ('Colorado', 'Pennsylvania', 0.9745975567693891),
#  ('Colorado', 'Rhode Island', 0.9953550177610494),
#  ('Colorado', 'South Carolina', 0.9199752654878162),
#  ('Colorado', 'South Dakota', 0.9606861775413615),
#  ('Colorado', 'Tennessee', 0.9596060857204475),
#  ('Colorado', 'Texas', 0.8909436727504226),
#  ('Colorado', 'Utah', 0.9906113783341056),
#  ('Colorado', 'Vermont', 0.9577724044484003),
#  ('Colorado', 'Virginia', 0.9592519308469748),
#  ('Colorado', 'Washington', 0.9886775311893314),
#  ('Colorado', 'West Virginia', 0.9564080790272395),
#  ('Colorado', 'Wisconsin', 0.9750258908662843),
#  ('Colorado', 'Wyoming', 0.9806268954507127),
#  ('Colorado', 'Puerto Rico', 0.30736305033842404),
#  ('Connecticut', 'Delaware', 0.9791809054770365),
#  ('Connecticut', 'District of Columbia', 0.7362175358432342),
#  ('Connecticut', 'Florida', 0.9736557546833453),
#  ('Connecticut', 'Georgia', 0.9267157799618537),
#  ('Connecticut', 'Hawaii', 0.5120559533981484),
#  ('Connecticut', 'Idaho', 0.9859206309998244),
#  ('Connecticut', 'Illinois', 0.9966539886803344),
#  ('Connecticut', 'Indiana', 0.9875770039959161),
#  ('Connecticut', 'Iowa', 0.9796099286926367),
#  ('Connecticut', 'Kansas', 0.9936139599257002),
#  ('Connecticut', 'Kentucky', 0.9783338406041604),
#  ('Connecticut', 'Louisiana', 0.9273886158391991),
#  ('Connecticut', 'Maine', 0.9659674201611346),
#  ('Connecticut', 'Maryland', 0.9298164508532963),
#  ('Connecticut', 'Massachusetts', 0.9959488320060272),
#  ('Connecticut', 'Michigan', 0.9845908707422414),
#  ('Connecticut', 'Minnesota', 0.9832727802731408),
#  ('Connecticut', 'Mississippi', 0.8867169090085499),
#  ('Connecticut', 'Missouri', 0.9821914581071868),
#  ('Connecticut', 'Montana', 0.9679265099675072),
#  ('Connecticut', 'Nebraska', 0.9906364876410749),
#  ('Connecticut', 'Nevada', 0.9547940473297636),
#  ('Connecticut', 'New Hampshire', 0.9718368736394335),
#  ('Connecticut', 'New Jersey', 0.9862201191940687),
#  ('Connecticut', 'New Mexico', 0.7648965845579822),
#  ('Connecticut', 'New York', 0.9876608693722068),
#  ('Connecticut', 'North Carolina', 0.9800887741701936),
#  ('Connecticut', 'North Dakota', 0.9718130795360745),
#  ('Connecticut', 'Ohio', 0.9812608105148144),
#  ('Connecticut', 'Oklahoma', 0.9877449553197386),
#  ('Connecticut', 'Oregon', 0.9906761909336256),
#  ('Connecticut', 'Pennsylvania', 0.9895703984996166),
#  ('Connecticut', 'Rhode Island', 0.9972601854056257),
#  ('Connecticut', 'South Carolina', 0.9565398348638816),
#  ('Connecticut', 'South Dakota', 0.9685528677912232),
#  ('Connecticut', 'Tennessee', 0.9827061201618015),
#  ('Connecticut', 'Texas', 0.8711164171648074),
#  ('Connecticut', 'Utah', 0.9893455603683826),
#  ('Connecticut', 'Vermont', 0.9667728194680786),
#  ('Connecticut', 'Virginia', 0.9846921757316403),
#  ('Connecticut', 'Washington', 0.9919796827789336),
#  ('Connecticut', 'West Virginia', 0.9679358859130021),
#  ('Connecticut', 'Wisconsin', 0.9851113473623473),
#  ('Connecticut', 'Wyoming', 0.9825393386915355),
#  ('Connecticut', 'Puerto Rico', 0.24076043103542075),
#  ('Delaware', 'District of Columbia', 0.8411562904570162),
#  ('Delaware', 'Florida', 0.956061676760233),
#  ('Delaware', 'Georgia', 0.9800018910210879),
#  ('Delaware', 'Hawaii', 0.48363952541047156),
#  ('Delaware', 'Idaho', 0.949197379023019),
#  ('Delaware', 'Illinois', 0.985618341434366),
#  ('Delaware', 'Indiana', 0.9756986915201235),
#  ('Delaware', 'Iowa', 0.95540580373653),
#  ('Delaware', 'Kansas', 0.9673386523292526),
#  ('Delaware', 'Kentucky', 0.967131852238016),
#  ('Delaware', 'Louisiana', 0.9835050509497941),
#  ('Delaware', 'Maine', 0.9425872210342915),
#  ('Delaware', 'Maryland', 0.9797938331599642),
#  ('Delaware', 'Massachusetts', 0.9735932333125126),
#  ('Delaware', 'Michigan', 0.9861150215407274),
#  ('Delaware', 'Minnesota', 0.9671456102245329),
#  ('Delaware', 'Mississippi', 0.961248427861466),
#  ('Delaware', 'Missouri', 0.9781235610528399),
#  ('Delaware', 'Montana', 0.9409144742138833),
#  ('Delaware', 'Nebraska', 0.9634167530852902),
#  ('Delaware', 'Nevada', 0.9131031725154757),
#  ('Delaware', 'New Hampshire', 0.9466665906188588),
#  ('Delaware', 'New Jersey', 0.9680916053389168),
#  ('Delaware', 'New Mexico', 0.6790934685025024),
#  ('Delaware', 'New York', 0.976467288501576),
#  ('Delaware', 'North Carolina', 0.9996878380979527),
#  ('Delaware', 'North Dakota', 0.9500834419104408),
#  ('Delaware', 'Ohio', 0.9798209189942666),
#  ('Delaware', 'Oklahoma', 0.967549359736977),
#  ('Delaware', 'Oregon', 0.9547866453173262),
#  ('Delaware', 'Pennsylvania', 0.9808010743348698),
#  ('Delaware', 'Rhode Island', 0.9667118942282916),
#  ('Delaware', 'South Carolina', 0.995213499726952),
#  ('Delaware', 'South Dakota', 0.9448833600546283),
#  ('Delaware', 'Tennessee', 0.9911023144687637),
#  ('Delaware', 'Texas', 0.8241996607645196),
#  ('Delaware', 'Utah', 0.9513637289228127),
#  ('Delaware', 'Vermont', 0.9433206477348264),
#  ('Delaware', 'Virginia', 0.9984552135573735),
#  ('Delaware', 'Washington', 0.9597099666319151),
#  ('Delaware', 'West Virginia', 0.9499001230072986),
#  ('Delaware', 'Wisconsin', 0.9659642009868304),
#  ('Delaware', 'Wyoming', 0.9494706685284567),
#  ('Delaware', 'Puerto Rico', 0.1443716187024486),
#  ('District of Columbia', 'Florida', 0.7979492140747596),
#  ('District of Columbia', 'Georgia', 0.9318532549985568),
#  ('District of Columbia', 'Hawaii', 0.37495119911708275),
#  ('District of Columbia', 'Idaho', 0.6321460013925584),
#  ('District of Columbia', 'Illinois', 0.7830666668778707),
#  ('District of Columbia', 'Indiana', 0.7035674789910766),
#  ('District of Columbia', 'Iowa', 0.6449009880693896),
#  ('District of Columbia', 'Kansas', 0.6799009725281614),
#  ('District of Columbia', 'Kentucky', 0.681580987637756),
#  ('District of Columbia', 'Louisiana', 0.9120625384800991),
#  ('District of Columbia', 'Maine', 0.6177878009513577),
#  ('District of Columbia', 'Maryland', 0.9293974371754538),
#  ('District of Columbia', 'Massachusetts', 0.7011206399160793),
#  ('District of Columbia', 'Michigan', 0.7444778796090802),
#  ('District of Columbia', 'Minnesota', 0.6777805459082294),
#  ('District of Columbia', 'Mississippi', 0.9373931402107116),
#  ('District of Columbia', 'Missouri', 0.7159339432431724),
#  ('District of Columbia', 'Montana', 0.6153681632819067),
#  ('District of Columbia', 'Nebraska', 0.6673589100571132),
#  ('District of Columbia', 'Nevada', 0.7277172522203887),
#  ('District of Columbia', 'New Hampshire', 0.6246101235087618),
#  ('District of Columbia', 'New Jersey', 0.7791384152201603),
#  ('District of Columbia', 'New Mexico', 0.5304859720716494),
#  ('District of Columbia', 'New York', 0.7979102809745562),
#  ('District of Columbia', 'North Carolina', 0.8374244388942698),
#  ('District of Columbia', 'North Dakota', 0.6378659438103431),
#  ('District of Columbia', 'Ohio', 0.7231261753433728),
#  ('District of Columbia', 'Oklahoma', 0.7006214973456949),
#  ('District of Columbia', 'Oregon', 0.6482450815337236),
#  ('District of Columbia', 'Pennsylvania', 0.7201477078682318),
#  ('District of Columbia', 'Rhode Island', 0.687799050591744),
#  ('District of Columbia', 'South Carolina', 0.8684141040025836),
#  ('District of Columbia', 'South Dakota', 0.6297502946746847),
#  ('District of Columbia', 'Tennessee', 0.7700783262042892),
#  ('District of Columbia', 'Texas', 0.7107816994837516),
#  ('District of Columbia', 'Utah', 0.6402885600792414),
#  ('District of Columbia', 'Vermont', 0.6189337269526329),
#  ('District of Columbia', 'Virginia', 0.8218713765096585),
#  ('District of Columbia', 'Washington', 0.6693341807674966),
#  ('District of Columbia', 'West Virginia', 0.6374221632923827),
#  ('District of Columbia', 'Wisconsin', 0.6733426784729911),
#  ('District of Columbia', 'Wyoming', 0.6314436887917464),
#  ('District of Columbia', 'Puerto Rico', 0.1893908850995855),
#  ('Florida', 'Georgia', 0.9329695930271129),
#  ('Florida', 'Hawaii', 0.5009129764416302),
#  ('Florida', 'Idaho', 0.9283652715622658),
#  ('Florida', 'Illinois', 0.9849584766194877),
#  ('Florida', 'Indiana', 0.9295245851268852),
#  ('Florida', 'Iowa', 0.9094320494738791),
#  ('Florida', 'Kansas', 0.9433896051053093),
#  ('Florida', 'Kentucky', 0.9093443929896509),
#  ('Florida', 'Louisiana', 0.9153203711850882),
#  ('Florida', 'Maine', 0.8838790639579464),
#  ('Florida', 'Maryland', 0.9372311055310156),
#  ('Florida', 'Massachusetts', 0.949587063940116),
#  ('Florida', 'Michigan', 0.929756490059379),
#  ('Georgia', 'Pennsylvania', 0.922799452850674),
#  ('Georgia', 'Rhode Island', 0.9006400393760878),
#  ('Georgia', 'South Carolina', 0.987343272154043),
#  ('Georgia', 'South Dakota', 0.8658288173501419),
#  ('Georgia', 'Tennessee', 0.9483221743618718),
#  ('Georgia', 'Texas', 0.8108247282154206),
#  ('Georgia', 'Utah', 0.8731103582333385),
#  ('Georgia', 'Vermont', 0.8608014230438883),
#  ('Georgia', 'Virginia', 0.9716841191248663),
#  ('Georgia', 'Washington', 0.8890098624269411),
#  ('Georgia', 'West Virginia', 0.872118046004124),
#  ('Georgia', 'Wisconsin', 0.8956577785107479),
#  ('Georgia', 'Wyoming', 0.8690022144078513),
#  ('Georgia', 'Puerto Rico', 0.1608081377180391),
#  ('Hawaii', 'Idaho', 0.46366467331794103),
#  ('Hawaii', 'Illinois', 0.5224887685774897),
#  ('Hawaii', 'Indiana', 0.46109597394887114),
#  ('Hawaii', 'Iowa', 0.4599738335041692),
#  ('Hawaii', 'Kansas', 0.48504314927214986),
#  ('Hawaii', 'Kentucky', 0.44474162695068975),
#  ('Hawaii', 'Louisiana', 0.42044866351123766),
#  ('Hawaii', 'Maine', 0.43414923042019243),
#  ('Hawaii', 'Maryland', 0.5002578801999635),
#  ('Hawaii', 'Massachusetts', 0.522495171940947),
#  ('Hawaii', 'Michigan', 0.4670210044546815),
#  ('Hawaii', 'Minnesota', 0.48415492105342084),
#  ('Hawaii', 'Mississippi', 0.38189312928312424),
#  ('Hawaii', 'Missouri', 0.454507268860179),
#  ('Hawaii', 'Montana', 0.44021816864224295),
#  ('Hawaii', 'Nebraska', 0.47328785780141963),
#  ('Hawaii', 'Nevada', 0.5891174207221784),
#  ('Hawaii', 'New Hampshire', 0.451660487551392),
#  ('Hawaii', 'New Jersey', 0.5840194320634683),
#  ('Hawaii', 'New Mexico', 0.4359846342690261),
#  ('Hawaii', 'New York', 0.5709372979587759),
#  ('Hawaii', 'North Carolina', 0.4705727853754952),
#  ('Hawaii', 'North Dakota', 0.4442638958930554),
#  ('Hawaii', 'Ohio', 0.45574553694499376),
#  ('Hawaii', 'Oklahoma', 0.5011791403785955),
#  ('Hawaii', 'Oregon', 0.5063783824601096),
#  ('Hawaii', 'Pennsylvania', 0.47363811751063956),
#  ('Hawaii', 'Rhode Island', 0.49916417598976726),
#  ('Hawaii', 'South Carolina', 0.4326833007980703),
#  ('Hawaii', 'South Dakota', 0.44270292290004876),
#  ('Hawaii', 'Tennessee', 0.45021921277551513),
#  ('Hawaii', 'Texas', 0.5089566211303531),
#  ('Hawaii', 'Utah', 0.47975735249809864),
#  ('Hawaii', 'Vermont', 0.44024537251996215),
#  ('Hawaii', 'Virginia', 0.5222315403910222),
#  ('Hawaii', 'Washington', 0.5632146632327488),
#  ('Hawaii', 'West Virginia', 0.43041464144072866),
#  ('Hawaii', 'Wisconsin', 0.46719062116858817),
#  ('Hawaii', 'Wyoming', 0.4509473216413106),
#  ('Hawaii', 'Puerto Rico', 0.20663109430411566),
#  ('Indiana', 'Wisconsin', 0.9990175706179795),
#  ('Indiana', 'Wyoming', 0.9938934232506147),
#  ('Indiana', 'Puerto Rico', 0.09350323473065358),
#  ('Iowa', 'Kansas', 0.9956205407781015),
#  ('Iowa', 'Kentucky', 0.9978726578578679),
#  ('Iowa', 'Louisiana', 0.8964787203779346),
#  ('Iowa', 'Maine', 0.998174823767419),
#  ('Iowa', 'Maryland', 0.8779077010913571),
#  ('Iowa', 'Massachusetts', 0.992014234473695),
#  ('Iowa', 'Michigan', 0.9898877242433545),
#  ('Iowa', 'Minnesota', 0.9985495475735949),
#  ('Iowa', 'Mississippi', 0.8528065166520149),
#  ('Iowa', 'Missouri', 0.994518440337838),
#  ('Iowa', 'Montana', 0.9967367044427421),
#  ('Iowa', 'Nebraska', 0.9974570614480931),
#  ('Iowa', 'Nevada', 0.8825402927464282),
#  ('Iowa', 'New Hampshire', 0.99934635702461),
#  ('Iowa', 'New Jersey', 0.9366570664996351),
#  ('Iowa', 'New Mexico', 0.6533384993703054),
#  ('Iowa', 'New York', 0.9392232089724817),
#  ('Iowa', 'North Carolina', 0.957311428354813),
#  ('Iowa', 'North Dakota', 0.9975569854574987),
#  ('Iowa', 'Ohio', 0.9931327464404553),
#  ('Iowa', 'Oklahoma', 0.9849158511412478),
#  ('Iowa', 'Oregon', 0.9940599615425761),
#  ('Iowa', 'Pennsylvania', 0.9946336821965802),
#  ('Iowa', 'Rhode Island', 0.9888574940980903),
#  ('Iowa', 'South Carolina', 0.936356360645361),
#  ('Iowa', 'South Dakota', 0.994685152403816),
#  ('Iowa', 'Tennessee', 0.9834090889135978),
#  ('Iowa', 'Texas', 0.7628164812011972),
#  ('Iowa', 'Utah', 0.9939698440344568),
#  ('Iowa', 'Vermont', 0.9983894284707286),
#  ('Iowa', 'Virginia', 0.9626857849690479),
#  ('Iowa', 'Washington', 0.9882176804439403),
#  ('Iowa', 'West Virginia', 0.998137641098828),
#  ('Iowa', 'Wisconsin', 0.9992349845154165),
#  ('Iowa', 'Wyoming', 0.9980295579565411),
#  ('Iowa', 'Puerto Rico', 0.0758257584707203),
#  ('Kansas', 'Kentucky', 0.9928756406002767),
#  ('Kansas', 'Louisiana', 0.9086939718991656),
#  ('Kansas', 'Maine', 0.9883915939463622),
#  ('Kansas', 'Maryland', 0.8998326036936702),
#  ('Kansas', 'Massachusetts', 0.9983893049395884),
#  ('Kansas', 'Michigan', 0.9902607671102917),
#  ('Kansas', 'Minnesota', 0.9957078506855443),
#  ('Kansas', 'Mississippi', 0.8647018572584986),
#  ('Kansas', 'Missouri', 0.9922310951238995),
#  ('Kansas', 'Montana', 0.98925525219567),
#  ('Kansas', 'Nebraska', 0.9996697262341284),
#  ('Kansas', 'Nevada', 0.9216599380173273),
#  ('Kansas', 'New Hampshire', 0.9917013031669861),
#  ('Kansas', 'New Jersey', 0.9629901091351979),
#  ('Kansas', 'New Mexico', 0.7151395282217222),
#  ('Kansas', 'New York', 0.9646444432304851),
#  ('Kansas', 'North Carolina', 0.9690970573302646),
#  ('Louisiana', 'Massachusetts', 0.9173387830424591),
#  ('Louisiana', 'Michigan', 0.9499335821547223),
#  ('Louisiana', 'Minnesota', 0.9145019280161106),
#  ('Louisiana', 'Mississippi', 0.9952344714132221),
#  ('Louisiana', 'Missouri', 0.9368725942729089),
#  ('Louisiana', 'Montana', 0.8800148230124457),
#  ('Louisiana', 'Nebraska', 0.9037238845051021),
#  ('Louisiana', 'Nevada', 0.8512421291838734),
#  ('Louisiana', 'New Hampshire', 0.8861966529080553),
#  ('Louisiana', 'New Jersey', 0.9204641662510806),
#  ('Louisiana', 'New Mexico', 0.5997932027759645),
#  ('Louisiana', 'New York', 0.934768036079241),
#  ('Louisiana', 'North Carolina', 0.9827667930162383),
#  ('Louisiana', 'North Dakota', 0.8936015370132614),
#  ('Louisiana', 'Ohio', 0.9406737353827557),
#  ('Louisiana', 'Oklahoma', 0.9151716996532553),
#  ('Louisiana', 'Oregon', 0.8874563326905546),
#  ('Louisiana', 'Pennsylvania', 0.9360236928140672),
#  ('Louisiana', 'Rhode Island', 0.9057431110550394),
#  ('Louisiana', 'South Carolina', 0.9949305425153186),
#  ('Louisiana', 'South Dakota', 0.8872686934917869),
#  ('Louisiana', 'Tennessee', 0.961906640930582),
#  ('Louisiana', 'Texas', 0.7690169897593997),
#  ('Louisiana', 'Utah', 0.8833443669113583),
#  ('Louisiana', 'Vermont', 0.8841049629527414),
#  ('Louisiana', 'Virginia', 0.9743180128044371),
#  ('Louisiana', 'Washington', 0.894091206683386),
#  ('Louisiana', 'West Virginia', 0.8956543714908537),
#  ('Louisiana', 'Wisconsin', 0.9118019615147968),
#  ('Louisiana', 'Wyoming', 0.8848995862728178),
#  ('Louisiana', 'Puerto Rico', 0.08304369001545472),
#  ('Maine', 'Maryland', 0.8581634326905824),
#  ('Maine', 'Massachusetts', 0.9827701648353049),
#  ('Maine', 'Michigan', 0.9846978664888196),
#  ('Maine', 'Minnesota', 0.9953422777574216),
#  ('Maine', 'Mississippi', 0.8402400963287212),
#  ('Maine', 'Missouri', 0.9912457086707572),
#  ('Maine', 'Montana', 0.9977415528652094),
#  ('Maine', 'Nebraska', 0.9916274293456675),
#  ('Maine', 'Nevada', 0.8530587855420861),
#  ('Maine', 'New Hampshire', 0.9995387512603169),
#  ('Maine', 'New Jersey', 0.9140617109234968),
#  ('Maine', 'New Mexico', 0.6139265814261686),
#  ('Maine', 'New York', 0.9173822903674385),
#  ('Maine', 'North Carolina', 0.944950685791104),
#  ('Maine', 'North Dakota', 0.9977416823888839),
#  ('Maine', 'Ohio', 0.9898098105278681),
#  ('Maine', 'Oklahoma', 0.9771443589366005),
#  ('Maine', 'Oregon', 0.986714363696472),
#  ('Maine', 'Pennsylvania', 0.9888855402554291),
#  ('Maine', 'Rhode Island', 0.9784033007928856),
#  ('Maine', 'South Carolina', 0.9257483554894829),
#  ('Maine', 'South Dakota', 0.9951135987480019),
#  ('Maine', 'Tennessee', 0.977337122596928),
#  ('Maine', 'Texas', 0.7240150296845479),
#  ('Maine', 'Utah', 0.9871340528975814),
#  ('Maine', 'Vermont', 0.9999496582673306),
#  ('Maine', 'Virginia', 0.9497143065364186),
#  ('Maine', 'Washington', 0.9784349087411812),
#  ('Maine', 'West Virginia', 0.9995915560640335),
#  ('Maine', 'Wisconsin', 0.9957800216336463),
#  ('Maine', 'Wyoming', 0.9947514415414964),
#  ('Maine', 'Puerto Rico', 0.023924231089706444),
#  ('Maryland', 'Massachusetts', 0.9138319253855043),
#  ('Maryland', 'Michigan', 0.9344284664835645),
#  ('Maryland', 'Minnesota', 0.8988296398462127),
#  ('Maryland', 'Mississippi', 0.9842716563713465),
#  ('Maryland', 'Missouri', 0.9180710305366123),
#  ('Maryland', 'Montana', 0.8565128029874598),
#  ('Maryland', 'Nebraska', 0.8921359510728193),
#  ('Maryland', 'Nevada', 0.8888072923600827),
#  ('Maryland', 'New Hampshire', 0.8643883449203611),
#  ('Maryland', 'New Jersey', 0.9429158168466193),
#  ('Maryland', 'New Mexico', 0.6581932750440233),
#  ('Maryland', 'New York', 0.9542809748771169),
#  ('Maryland', 'North Carolina', 0.9774979898403984),
#  ('Maryland', 'North Dakota', 0.8710823696187278),
#  ('Maryland', 'Ohio', 0.9218293887614787),
#  ('Maryland', 'Oklahoma', 0.9077323330253556),
#  ('Maryland', 'Oregon', 0.8812545793641273),
#  ('Maryland', 'Pennsylvania', 0.9226330289592869),
#  ('Maryland', 'Rhode Island', 0.9032248099649531),
#  ('Maryland', 'South Carolina', 0.9837601392707267),
#  ('Maryland', 'South Dakota', 0.8646543687303286),
#  ('Maryland', 'Tennessee', 0.9461182785223653),
#  ('Maryland', 'Texas', 0.8214487284669354),
#  ('Maryland', 'Utah', 0.8747899520703574),
#  ('Maryland', 'Vermont', 0.8593870441664286),
#  ('Maryland', 'Virginia', 0.9738485419018803),
#  ('Maryland', 'Washington', 0.8951603131034304),
#  ('Maryland', 'West Virginia', 0.8698584114841482),
#  ('Maryland', 'Wisconsin', 0.8955467820234344),
#  ('Maryland', 'Wyoming', 0.8687407968234541),
#  ('Maryland', 'Puerto Rico', 0.17617635251332),
#  ('Massachusetts', 'Michigan', 0.9909027496569085),
#  ('Massachusetts', 'Minnesota', 0.9946269119840899),
#  ('Massachusetts', 'Mississippi', 0.8747245619494947),
#  ('Massachusetts', 'Missouri', 0.9909792596249392),
#  ('Massachusetts', 'Montana', 0.9831373388346697),
#  ('Massachusetts', 'Nebraska', 0.9971596519959282),
#  ('Massachusetts', 'Nevada', 0.9310262448502432),
#  ('Massachusetts', 'New Hampshire', 0.9872705678648979),
#  ('Massachusetts', 'New Jersey', 0.9729749912752267),
#  ('Massachusetts', 'New Mexico', 0.7182122983932853),
#  ('Massachusetts', 'New York', 0.9743190932905994),
#  ('Massachusetts', 'North Carolina', 0.9742223390263682),
#  ('Massachusetts', 'North Dakota', 0.9860504330327251),
#  ('Massachusetts', 'Ohio', 0.9899733364301412),
#  ('Massachusetts', 'Oklahoma', 0.9905325931919812),
#  ('Massachusetts', 'Oregon', 0.996833594461054),
#  ('Missouri', 'Ohio', 0.9999048245897026),
#  ('Missouri', 'Oklahoma', 0.9857802336085009),
#  ('Missouri', 'Oregon', 0.9857410130827915),
#  ('Missouri', 'Pennsylvania', 0.9989004953832753),
#  ('Missouri', 'Rhode Island', 0.985051148727489),
#  ('Missouri', 'South Carolina', 0.967079980574587),
#  ('Missouri', 'South Dakota', 0.9888728279303628),
#  ('Missouri', 'Tennessee', 0.9966573540892071),
#  ('Missouri', 'Texas', 0.7656415707643981),
#  ('Missouri', 'Utah', 0.9846342882008762),
#  ('Missouri', 'Vermont', 0.9914486043894203),
#  ('Missouri', 'Virginia', 0.9815072846001581),
#  ('Missouri', 'Washington', 0.9822805791208251),
#  ('Missouri', 'West Virginia', 0.9940846637258095),
#  ('Missouri', 'Wisconsin', 0.997187289277903),
#  ('Missouri', 'Wyoming', 0.9894297779862207),
#  ...]

# %%
age_columns = ['Age0_18', 'Age_19_25', 'Age_26_34', 'Age_35_54', 'Age_55_64', 'Age_65_plus']
age_similarity = compute_cosine_similarity(data, age_columns)
age_similarity
# Out:
# [('Alabama', 'Alaska', 0.9890460096780324),
#  ('Alabama', 'Arizona', 0.9988976158758918),
#  ('Alabama', 'Arkansas', 0.9995096916863627),
#  ('Alabama', 'California', 0.9960890669856748),
#  ('Alabama', 'Colorado', 0.9959837164034675),
#  ('Alabama', 'Connecticut', 0.9983735900861956),
#  ('Alabama', 'Delaware', 0.9980908911167147),
#  ('Alabama', 'District of Columbia', 0.9583185024907371),
#  ('Alabama', 'Florida', 0.9942481155288823),
#  ('Alabama', 'Georgia', 0.9957790780355167),
#  ('Alabama', 'Hawaii', 0.9976775338843018),
#  ('Alabama', 'Idaho', 0.9963529442086612),
#  ('Alabama', 'Illinois', 0.9988461786032494),
#  ('Alabama', 'Indiana', 0.9993027706710572),
#  ('Alabama', 'Iowa', 0.9996986187893946),
#  ('Alabama', 'Kansas', 0.9981108713364403),
#  ('Alabama', 'Kentucky', 0.9997874455622177),
#  ('Alabama', 'Louisiana', 0.998415759816853),
#  ('Alabama', 'Maine', 0.9902628606349385),
#  ('Alabama', 'Maryland', 0.9981820487462933),
#  ('Alabama', 'Massachusetts', 0.9971455326118237),
#  ('Alabama', 'Michigan', 0.9995659773474094),
#  ('Alabama', 'Minnesota', 0.9990526580946041),
#  ('Alabama', 'Mississippi', 0.9986440066662325),
#  ('Alabama', 'Missouri', 0.9996893581833973),
#  ('Alabama', 'Montana', 0.9979730655012303),
#  ('Alabama', 'Nebraska', 0.9978563667787517),
#  ('Alabama', 'Nevada', 0.9983900951224939),
#  ('Alabama', 'New Hampshire', 0.9940143136590022),
#  ('Alabama', 'New Jersey', 0.9985177111013401),
#  ('Alabama', 'New Mexico', 0.9988032411182733),
#  ('Alabama', 'New York', 0.9976966771973916),
#  ('Alabama', 'North Carolina', 0.999351373040421),
#  ('Alabama', 'North Dakota', 0.9963772636472236),
#  ('Alabama', 'Ohio', 0.9998000300211686),
#  ('Alabama', 'Oklahoma', 0.9977951372749533),
#  ('Alabama', 'Oregon', 0.9982351938177965),
#  ('Alabama', 'Pennsylvania', 0.9982827934837947),
#  ('Alabama', 'Rhode Island', 0.9972879587863703),
#  ('Alabama', 'South Carolina', 0.9995787700189511),
#  ('Alabama', 'South Dakota', 0.997919493722197),
#  ('Alabama', 'Tennessee', 0.9995505777407553),
#  ('Alabama', 'Texas', 0.9897474377461211),
#  ('Alabama', 'Utah', 0.9729242929574072),
#  ('Alabama', 'Vermont', 0.99234118822464),
#  ('Alabama', 'Virginia', 0.9988528384074655),
#  ('Alabama', 'Washington', 0.9980562559095795),
#  ('Alabama', 'West Virginia', 0.9958212197738181),
#  ('Alabama', 'Wisconsin', 0.9997099088698949),
#  ('Alabama', 'Wyoming', 0.9979748359158608),
#  ('Alabama', 'Puerto Rico', 0.9946642800772773),
#  ('Alaska', 'Arizona', 0.9878192964549785),
#  ('Alaska', 'Arkansas', 0.9904437441264904),
#  ('Alaska', 'California', 0.9957512667972234),
#  ('Alaska', 'Colorado', 0.9954517366721864),
#  ('Alaska', 'Connecticut', 0.9842645743632498),
#  ('Alaska', 'Delaware', 0.9803191345740893),
#  ('Alaska', 'District of Columbia', 0.9656815952430567),
#  ('Alaska', 'Florida', 0.9692711360035347),
#  ('Alaska', 'Georgia', 0.9969772612126191),
#  ('Alaska', 'Hawaii', 0.9818690686503471),
#  ('Alaska', 'Idaho', 0.9935459295640319),
#  ('Alaska', 'Illinois', 0.9937302515160032),
#  ('Alaska', 'Indiana', 0.9937000099828475),
#  ('Alaska', 'Iowa', 0.9903394493951061),
#  ('Alaska', 'Kansas', 0.9941080902303786),
#  ('Alaska', 'Kentucky', 0.9910562993308741),
#  ('Alaska', 'Louisiana', 0.9953486136303814),
#  ('Alaska', 'Maine', 0.9632411017333855),
#  ('Alaska', 'Maryland', 0.9924842442417513),
#  ('Alaska', 'Massachusetts', 0.9857307151620438),
#  ('Alaska', 'Michigan', 0.9863948113364363),
#  ('Alaska', 'Minnesota', 0.9937389990455541),
#  ('Alaska', 'Mississippi', 0.9920866640302161),
#  ('Alaska', 'Missouri', 0.9900664770187515),
#  ('Alaska', 'Montana', 0.9799289279467599),
#  ('Alaska', 'Nebraska', 0.9949451358251777),
#  ('Alaska', 'Nevada', 0.9925080047982386),
#  ('Alaska', 'New Hampshire', 0.9743973206824248),
#  ('Alaska', 'New Jersey', 0.9897608643104184),
#  ('Alaska', 'New Mexico', 0.9885379677306099),
#  ('Alaska', 'New York', 0.9881179936189002),
#  ('Alaska', 'North Carolina', 0.9908271120910432),
#  ('Alaska', 'North Dakota', 0.9941228509884938),
#  ('Alaska', 'Ohio', 0.9888555734053986),
#  ('Alaska', 'Oklahoma', 0.9947995846971508),
#  ('Alaska', 'Oregon', 0.9851330157009482),
#  ('Alaska', 'Pennsylvania', 0.981639318549963),
#  ('Alaska', 'Rhode Island', 0.9826154112354819),
#  ('Alaska', 'South Carolina', 0.9852329144882577),
#  ('Alaska', 'South Dakota', 0.9913953296181434),
#  ('Alaska', 'Tennessee', 0.9912097057989342),
#  ('Alaska', 'Texas', 0.9988327354140955),
#  ('Alaska', 'Utah', 0.9911623816656234),
#  ('Alaska', 'Vermont', 0.9669955985651107),
#  ('Alaska', 'Virginia', 0.9919808801095863),
#  ('Alaska', 'Washington', 0.9930559970773044),
#  ('Alaska', 'West Virginia', 0.9720875599646012),
#  ('Alaska', 'Wisconsin', 0.9877966684048183),
#  ('Alaska', 'Wyoming', 0.9921169845076856),
#  ('Alaska', 'Puerto Rico', 0.9697314844995928),
#  ('Arizona', 'Arkansas', 0.999502448804678),
#  ('Arizona', 'California', 0.9952045372769042),
#  ('Arizona', 'Colorado', 0.994571370665331),
#  ('Arizona', 'Connecticut', 0.995311314952881),
#  ('Arizona', 'Delaware', 0.9970866663946398),
#  ('Arizona', 'District of Columbia', 0.9587040960551365),
#  ('Arizona', 'Florida', 0.9937605528329956),
#  ('Arizona', 'Georgia', 0.9942562180527766),
#  ('Arizona', 'Hawaii', 0.9974918069944796),
#  ('Arizona', 'Idaho', 0.9971408497445613),
#  ('Arizona', 'Illinois', 0.9973176940122779),
#  ('Arizona', 'Indiana', 0.9983160151386902),
#  ('Arizona', 'Iowa', 0.999176159645493),
#  ('Arizona', 'Kansas', 0.9981639592760837),
#  ('Arizona', 'Kentucky', 0.9981695386450308),
#  ('Arizona', 'Louisiana', 0.9979544645943037),
#  ('Arizona', 'Maine', 0.9870038098014564),
#  ('Arizona', 'Maryland', 0.9955835690954672),
#  ('Arizona', 'Massachusetts', 0.9947311912790684),
#  ('Arizona', 'Michigan', 0.9977807874393139),
#  ('Arizona', 'Minnesota', 0.9975709817144447),
#  ('Arizona', 'Mississippi', 0.998042957999467),
#  ('Arizona', 'Missouri', 0.9989313760542932),
#  ('Arizona', 'Montana', 0.9968740963808868),
#  ('Arizona', 'Nebraska', 0.998063130893),
#  ('Arizona', 'Nevada', 0.9973585716346065),
#  ('Arizona', 'New Hampshire', 0.9896337706907047),
#  ('Arizona', 'New Jersey', 0.9958074163384296),
#  ('Arizona', 'New Mexico', 0.9992843113205022),
#  ('Arizona', 'New York', 0.9960073093988449),
#  ('Arizona', 'North Carolina', 0.9978334919624102),
#  ('Arizona', 'North Dakota', 0.9964372204432094),
#  ('Arizona', 'Ohio', 0.9983782377117466),
#  ('Arizona', 'Oklahoma', 0.9981958309929673),
#  ('Arizona', 'Oregon', 0.997147938968682),
#  ('Arizona', 'Pennsylvania', 0.9965110100347137),
#  ('Arizona', 'Rhode Island', 0.9948095430124657),
#  ('Arizona', 'South Carolina', 0.9985477013388473),
#  ('Arizona', 'South Dakota', 0.9984605189073583),
#  ('Arizona', 'Tennessee', 0.9982054523895239),
#  ('Arizona', 'Texas', 0.9898301893518706),
#  ('Arizona', 'Utah', 0.9759899089294568),
#  ('Arizona', 'Vermont', 0.9890700088419759),
#  ('Arizona', 'Virginia', 0.9968794915870431),
#  ('Arizona', 'Washington', 0.996759251586166),
#  ('Arizona', 'West Virginia', 0.9938869846526016),
#  ('Arizona', 'Wisconsin', 0.9977706826649873),
#  ('California', 'Florida', 0.9850663242235933),
#  ('California', 'Georgia', 0.9985916273721146),
#  ('California', 'Hawaii', 0.992171968561031),
#  ('California', 'Idaho', 0.9943067784938251),
#  ('California', 'Illinois', 0.9989852124342059),
#  ('California', 'Indiana', 0.9978553501798513),
#  ('California', 'Iowa', 0.9957419575662477),
#  ('California', 'Kansas', 0.9962882010346008),
#  ('California', 'Kentucky', 0.9970473768439913),
#  ('California', 'Louisiana', 0.9980769960451903),
#  ('California', 'Maine', 0.9789683161266901),
#  ('California', 'Maryland', 0.9983002068336961),
#  ('California', 'Massachusetts', 0.9958361916693317),
#  ('California', 'Michigan', 0.9948833591992491),
#  ('California', 'Minnesota', 0.998313079264539),
#  ('California', 'Mississippi', 0.9956347008396152),
#  ('California', 'Missouri', 0.9964297279753641),
#  ('California', 'Montana', 0.9902009921143594),
#  ('California', 'Nebraska', 0.9969272449823277),
#  ('California', 'Nevada', 0.9990198103514898),
#  ('California', 'New Hampshire', 0.9871436501385037),
#  ('California', 'New Jersey', 0.9970277730527732),
#  ('California', 'New Mexico', 0.9939850711480482),
#  ('California', 'New York', 0.9974431136579563),
#  ('California', 'North Carolina', 0.997564798837965),
#  ('California', 'North Dakota', 0.9972897742642083),
#  ('California', 'Ohio', 0.9958705624249047),
#  ('California', 'Oklahoma', 0.9968870842195755),
#  ('California', 'Oregon', 0.9954785402917992),
#  ('California', 'Pennsylvania', 0.9923220285088759),
#  ('California', 'Rhode Island', 0.9938582348426411),
#  ('California', 'South Carolina', 0.9944586009632478),
#  ('California', 'South Dakota', 0.9946136210466329),
#  ('California', 'Tennessee', 0.9977678941474848),
#  ('California', 'Texas', 0.9959245682011614),
#  ('California', 'Utah', 0.981521733991745),
#  ('California', 'Vermont', 0.9821938106800562),
#  ('California', 'Virginia', 0.9984458839970783),
#  ('California', 'Washington', 0.9990865462827562),
#  ('California', 'West Virginia', 0.985515678910743),
#  ('California', 'Wisconsin', 0.9952847921472974),
#  ('California', 'Wyoming', 0.9947166198641543),
#  ('California', 'Puerto Rico', 0.9859559442568504),
#  ('Colorado', 'Connecticut', 0.994745311849304),
#  ('Colorado', 'Delaware', 0.992001324266366),
#  ('Colorado', 'District of Columbia', 0.9765423964089072),
#  ('Colorado', 'Florida', 0.9856463570910851),
#  ('Colorado', 'Georgia', 0.9980356893951907),
#  ('Colorado', 'Hawaii', 0.9928441411300187),
#  ('Colorado', 'Idaho', 0.9932894093498443),
#  ('Colorado', 'Illinois', 0.9990494923133356),
#  ('Colorado', 'Indiana', 0.9975208342261608),
#  ('Colorado', 'Iowa', 0.9955301624783482),
#  ('Colorado', 'Kansas', 0.9956505781287002),
#  ('Colorado', 'Kentucky', 0.9970672348888054),
#  ('Colorado', 'Louisiana', 0.99762484452888),
#  ('Colorado', 'Maine', 0.9808298819363374),
#  ('Colorado', 'Maryland', 0.9987191292106429),
#  ('Colorado', 'Massachusetts', 0.9967972758785991),
#  ('Colorado', 'Michigan', 0.9951804115660124),
#  ('Colorado', 'Minnesota', 0.998547299663973),
#  ('Colorado', 'Mississippi', 0.9947677590388263),
#  ('Colorado', 'Missouri', 0.9966233022469072),
#  ('Colorado', 'Montana', 0.9906245442589464),
#  ('Colorado', 'Nebraska', 0.9964873181765187),
#  ('Colorado', 'Nevada', 0.9989957307103456),
#  ('Colorado', 'New Hampshire', 0.988807321996699),
#  ('Colorado', 'New Jersey', 0.9974079189650686),
#  ('Colorado', 'New Mexico', 0.9935767409757267),
#  ('Colorado', 'New York', 0.9980013550817639),
#  ('Colorado', 'North Carolina', 0.9975478621361089),
#  ('Colorado', 'North Dakota', 0.997096739157441),
#  ('Colorado', 'Ohio', 0.9961714395081999),
#  ('Colorado', 'Oklahoma', 0.9962918762397818),
#  ('Colorado', 'Oregon', 0.9961234764740894),
#  ('Colorado', 'Pennsylvania', 0.9931430726475082),
#  ('Colorado', 'Rhode Island', 0.9947233567460367),
#  ('Colorado', 'South Carolina', 0.9946201431206798),
#  ('Colorado', 'South Dakota', 0.9945111713135582),
#  ('Colorado', 'Tennessee', 0.9979269110192625),
#  ('Colorado', 'Texas', 0.994744298846934),
#  ('Colorado', 'Utah', 0.9788282253795717),
#  ('Colorado', 'Vermont', 0.9836095773272542),
#  ('Colorado', 'Virginia', 0.9985700300239314),
#  ('Colorado', 'Washington', 0.9994479702201359),
#  ('Colorado', 'West Virginia', 0.9861084740283892),
#  ('Colorado', 'Wisconsin', 0.9956427821146168),
#  ('Colorado', 'Wyoming', 0.994904240309628),
#  ('Colorado', 'Puerto Rico', 0.9857479003959005),
#  ('Connecticut', 'Delaware', 0.9983357279614112),
#  ('Connecticut', 'District of Columbia', 0.9604231005763387),
#  ('Connecticut', 'Florida', 0.9956522283843486),
#  ('Connecticut', 'Georgia', 0.9928025787973084),
#  ('Connecticut', 'Hawaii', 0.9973095971154542),
#  ('Connecticut', 'Idaho', 0.9903463126490221),
#  ('Connecticut', 'Illinois', 0.9974884199468601),
#  ('Connecticut', 'Indiana', 0.9965514886620499),
#  ('Connecticut', 'Iowa', 0.9969140540072409),
#  ('Connecticut', 'Kansas', 0.9934952830649223),
#  ('Connecticut', 'Kentucky', 0.9984198891342987),
#  ('Connecticut', 'Louisiana', 0.9947303492251691),
#  ('Connecticut', 'Maine', 0.9946974301578712),
#  ('Connecticut', 'Maryland', 0.9981957659884003),
#  ('Connecticut', 'Massachusetts', 0.9989745516695074),
#  ('Connecticut', 'Michigan', 0.9992454223124456),
#  ('Connecticut', 'Minnesota', 0.9974781710734998),
#  ('Connecticut', 'Mississippi', 0.9947052991162094),
#  ('Connecticut', 'Missouri', 0.9979211410528064),
#  ('Connecticut', 'Montana', 0.9975715387778818),
#  ('Connecticut', 'Nebraska', 0.9933623296971825),
#  ('Connecticut', 'Nevada', 0.9971612858433805),
#  ('Connecticut', 'New Hampshire', 0.998353525218745),
#  ('Connecticut', 'New Jersey', 0.998977932371211),
#  ('Connecticut', 'New Mexico', 0.9949692034221287),
#  ('Connecticut', 'New York', 0.9983976036236677),
#  ('Connecticut', 'North Carolina', 0.9983148527124881),
#  ('Connecticut', 'North Dakota', 0.992721912694887),
#  ('Connecticut', 'Ohio', 0.9987830171287175),
#  ('Connecticut', 'Oklahoma', 0.9930691243548408),
#  ('Connecticut', 'Oregon', 0.9987351718191056),
#  ('Connecticut', 'Pennsylvania', 0.9992134696501876),
#  ('Connecticut', 'Rhode Island', 0.9991874120327465),
#  ('Connecticut', 'South Carolina', 0.9988903683778549),
#  ('Connecticut', 'South Dakota', 0.9937040137080406),
#  ('Connecticut', 'Tennessee', 0.9984530135197107),
#  ('Connecticut', 'Texas', 0.9836458352387579),
#  ('Connecticut', 'Utah', 0.9609132344911898),
#  ('Connecticut', 'Vermont', 0.9961355804801629),
#  ('Connecticut', 'Virginia', 0.9982996451327781),
#  ('Connecticut', 'Washington', 0.9972134993339782),
#  ('Connecticut', 'West Virginia', 0.9972362679487149),
#  ('Connecticut', 'Wisconsin', 0.9992484862178521),
#  ('Connecticut', 'Wyoming', 0.9945177735102988),
#  ('Connecticut', 'Puerto Rico', 0.9954565152785626),
#  ('Delaware', 'District of Columbia', 0.9578609322203849),
#  ('Delaware', 'Florida', 0.9983840299588134),
#  ('Delaware', 'Georgia', 0.9890615120776245),
#  ('Delaware', 'Hawaii', 0.9992828303272083),
#  ('Delaware', 'Idaho', 0.9907097637892095),
#  ('Delaware', 'Illinois', 0.9955142064280803),
#  ('Delaware', 'Indiana', 0.9953742768701764),
#  ('Delaware', 'Iowa', 0.9973096354975933),
#  ('Delaware', 'Kansas', 0.9935202275102809),
#  ('Delaware', 'Kentucky', 0.9971753386142015),
#  ('Delaware', 'Louisiana', 0.9938137847922418),
#  ('Delaware', 'Maine', 0.9961908021504396),
#  ('Delaware', 'Maryland', 0.9951874767444163),
#  ('Delaware', 'Massachusetts', 0.997420651198301),
#  ('Delaware', 'Michigan', 0.9989787658274707),
#  ('Delaware', 'Minnesota', 0.9960551010454751),
#  ('Delaware', 'Mississippi', 0.9938475343751014),
#  ('Delaware', 'Missouri', 0.9982398548354613),
#  ('Delaware', 'Montana', 0.9994702309883667),
#  ('Delaware', 'Nebraska', 0.9934831369456708),
#  ('Delaware', 'Nevada', 0.9953694066642224),
#  ('Delaware', 'New Hampshire', 0.9969831963369785),
#  ('Delaware', 'New Jersey', 0.9961726252455291),
#  ('Delaware', 'New Mexico', 0.9968546213518537),
#  ('Delaware', 'New York', 0.9970175502020452),
#  ('Delaware', 'North Carolina', 0.9966541873163413),
#  ('Delaware', 'North Dakota', 0.9928845589652832),
#  ('Delaware', 'Ohio', 0.9986305970782157),
#  ('Delaware', 'Oklahoma', 0.9931738566116944),
#  ('Delaware', 'Oregon', 0.9988825828092951),
#  ('Delaware', 'Pennsylvania', 0.9998082495006918),
#  ('Delaware', 'Rhode Island', 0.9983719858603011),
#  ('Delaware', 'South Carolina', 0.9992666569860146),
#  ('Delaware', 'South Dakota', 0.9954693833402185),
#  ('Delaware', 'Tennessee', 0.9973599441176899),
#  ('Delaware', 'Texas', 0.9802625715828838),
#  ('Delaware', 'Utah', 0.9589682017020749),
#  ('Delaware', 'Vermont', 0.997128620713313),
#  ('Delaware', 'Virginia', 0.9959088465826937),
#  ('Delaware', 'Washington', 0.9955957746938248),
#  ('Delaware', 'West Virginia', 0.9986627013828165),
#  ('Delaware', 'Wisconsin', 0.9986699871423294),
#  ('Delaware', 'Wyoming', 0.9954541264541337),
#  ('Delaware', 'Puerto Rico', 0.9972663418584241),
#  ('District of Columbia', 'Florida', 0.9517525624604009),
#  ('District of Columbia', 'Georgia', 0.9635579653432415),
#  ('District of Columbia', 'Hawaii', 0.9604671373370396),
#  ('District of Columbia', 'Idaho', 0.9499020786190625),
#  ('District of Columbia', 'Illinois', 0.9676289848956767),
#  ('District of Columbia', 'Indiana', 0.9604836406165839),
#  ('District of Columbia', 'Iowa', 0.956447028411983),
#  ('District of Columbia', 'Kansas', 0.956162025160245),
#  ('District of Columbia', 'Kentucky', 0.9599608298911502),
#  ('District of Columbia', 'Louisiana', 0.9618670764860185),
#  ('District of Columbia', 'Maine', 0.9450284260357824),
#  ('District of Columbia', 'Maryland', 0.9675455092373444),
#  ('District of Columbia', 'Massachusetts', 0.9718819905828819),
#  ('District of Columbia', 'Michigan', 0.9594062814717774),
#  ('District of Columbia', 'Minnesota', 0.965505666802768),
#  ('District of Columbia', 'Mississippi', 0.9512841465885238),
#  ('District of Columbia', 'Missouri', 0.9618705207635421),
#  ('District of Columbia', 'Montana', 0.9532827778613993),
#  ('District of Columbia', 'Nebraska', 0.9598103282246944),
#  ('District of Columbia', 'Nevada', 0.969767175193877),
#  ('District of Columbia', 'New Hampshire', 0.9562377933574512),
#  ('District of Columbia', 'New Jersey', 0.9636794813953057),
#  ('District of Columbia', 'New Mexico', 0.9542738519806057),
#  ('District of Columbia', 'New York', 0.9736939858097141),
#  ('District of Columbia', 'North Carolina', 0.9625009359656248),
#  ('District of Columbia', 'North Dakota', 0.9692378740374545),
#  ('District of Columbia', 'Ohio', 0.9603373774498973),
#  ('District of Columbia', 'Oklahoma', 0.9589632131821479),
#  ('District of Columbia', 'Oregon', 0.968770395263949),
#  ('District of Columbia', 'Pennsylvania', 0.9595804860891015),
#  ('District of Columbia', 'Rhode Island', 0.9672398214323141),
#  ('District of Columbia', 'South Carolina', 0.9581619684485172),
#  ('District of Columbia', 'South Dakota', 0.957134787475968),
#  ('District of Columbia', 'Tennessee', 0.9645793528107983),
#  ('District of Columbia', 'Texas', 0.9619821113206568),
#  ('District of Columbia', 'Utah', 0.9413659935698069),
#  ('District of Columbia', 'Vermont', 0.9487918922124842),
#  ('District of Columbia', 'Virginia', 0.9665947957186661),
#  ('District of Columbia', 'Washington', 0.9729488202654656),
#  ('District of Columbia', 'West Virginia', 0.9449882637226652),
#  ('District of Columbia', 'Wisconsin', 0.9587527265983268),
#  ('District of Columbia', 'Wyoming', 0.9571633263238631),
#  ('District of Columbia', 'Puerto Rico', 0.949803127352798),
#  ('Florida', 'Georgia', 0.9820244872386329),
#  ('Florida', 'Hawaii', 0.997726341518373),
#  ('Georgia', 'Nevada', 0.9980314157962586),
#  ('Georgia', 'New Hampshire', 0.9846988914408186),
#  ('Georgia', 'New Jersey', 0.9968549492332903),
#  ('Georgia', 'New Mexico', 0.9935332166786774),
#  ('Georgia', 'New York', 0.9944666463971772),
#  ('Georgia', 'North Carolina', 0.9975421631112541),
#  ('Georgia', 'North Dakota', 0.9951029734361642),
#  ('Georgia', 'Ohio', 0.9950611284997033),
#  ('Georgia', 'Oklahoma', 0.9974699207898094),
#  ('Georgia', 'Oregon', 0.9926663352067006),
#  ('Georgia', 'Pennsylvania', 0.9902541294629441),
#  ('Georgia', 'Rhode Island', 0.9906052525430606),
#  ('Georgia', 'South Carolina', 0.9935113540887264),
#  ('Georgia', 'South Dakota', 0.9943200531192122),
#  ('Georgia', 'Tennessee', 0.9971204125632386),
#  ('Georgia', 'Texas', 0.9978033373827949),
#  ('Georgia', 'Utah', 0.9852989784151),
#  ('Georgia', 'Vermont', 0.9789276921557954),
#  ('Georgia', 'Virginia', 0.9979078399892166),
#  ('Georgia', 'Washington', 0.9973371162051905),
#  ('Georgia', 'West Virginia', 0.9842207249688786),
#  ('Georgia', 'Wisconsin', 0.9946424906403297),
#  ('Georgia', 'Wyoming', 0.9945541830036098),
#  ('Georgia', 'Puerto Rico', 0.983287017870335),
#  ('Hawaii', 'Idaho', 0.9917026915575803),
#  ('Hawaii', 'Illinois', 0.9958040536161591),
#  ('Hawaii', 'Indiana', 0.9954350299859656),
#  ('Hawaii', 'Iowa', 0.9971347303762637),
#  ('Hawaii', 'Kansas', 0.993752501944869),
#  ('Hawaii', 'Kentucky', 0.9970381865703817),
#  ('Hawaii', 'Louisiana', 0.9941177783956395),
#  ('Hawaii', 'Maine', 0.9945078997626665),
#  ('Hawaii', 'Maryland', 0.9953685330452694),
#  ('Hawaii', 'Massachusetts', 0.9970809505749112),
#  ('Hawaii', 'Michigan', 0.9978507552748878),
#  ('Hawaii', 'Minnesota', 0.9963996594615522),
#  ('Hawaii', 'Mississippi', 0.9937584527426456),
#  ('Hawaii', 'Missouri', 0.9982504746171262),
#  ('Hawaii', 'Montana', 0.9977928612046792),
#  ('Hawaii', 'Nebraska', 0.9941359619960691),
#  ('Hawaii', 'Nevada', 0.9962179046002213),
#  ('Hawaii', 'New Hampshire', 0.9950201734878282),
#  ('Hawaii', 'New Jersey', 0.9962363925234545),
#  ('Hawaii', 'New Mexico', 0.9965048721782754),
#  ('Hawaii', 'New York', 0.996832031552031),
#  ('Hawaii', 'North Carolina', 0.9970486844271512),
#  ('Hawaii', 'North Dakota', 0.9924468369840613),
#  ('Hawaii', 'Ohio', 0.9981772696418987),
#  ('Hawaii', 'Oklahoma', 0.9939938747570279),
#  ('Hawaii', 'Oregon', 0.9989501035408529),
#  ('Hawaii', 'Pennsylvania', 0.9990383986929816),
#  ('Hawaii', 'Rhode Island', 0.9969659220298649),
#  ('Hawaii', 'South Carolina', 0.9989863689386215),
#  ('Hawaii', 'South Dakota', 0.9959017972640652),
#  ('Illinois', 'Maryland', 0.9996443515314103),
#  ('Illinois', 'Massachusetts', 0.9977547811815083),
#  ('Illinois', 'Michigan', 0.9981132015023688),
#  ('Illinois', 'Minnesota', 0.9998262858797391),
#  ('Illinois', 'Mississippi', 0.9977994128550347),
#  ('Illinois', 'Missouri', 0.9989215093767901),
#  ('Illinois', 'Montana', 0.9946972615949343),
#  ('Illinois', 'Nebraska', 0.9980806686548709),
#  ('Illinois', 'Nevada', 0.9997179950303837),
#  ('Illinois', 'New Hampshire', 0.9921744374182946),
#  ('Illinois', 'New Jersey', 0.9991604049932695),
#  ('Illinois', 'New Mexico', 0.9967749374069161),
#  ('Illinois', 'New York', 0.9985996058536479),
#  ('Illinois', 'North Carolina', 0.9995353695009395),
#  ('Illinois', 'North Dakota', 0.9973292880261678),
#  ('Illinois', 'Ohio', 0.9987928436433263),
#  ('Illinois', 'Oklahoma', 0.9979800654194817),
#  ('Illinois', 'Oregon', 0.997802148586236),
#  ('Illinois', 'Pennsylvania', 0.9963247045973168),
#  ('Illinois', 'Rhode Island', 0.9966146865276232),
#  ('Illinois', 'South Carolina', 0.997842690232619),
#  ('Illinois', 'South Dakota', 0.996885420565736),
#  ('Illinois', 'Tennessee', 0.9996981350667993),
#  ('Illinois', 'Texas', 0.9937179841254893),
#  ('Illinois', 'Utah', 0.9773328292726391),
#  ('Illinois', 'Vermont', 0.988342383278527),
#  ('Illinois', 'Virginia', 0.9998165599503201),
#  ('Illinois', 'Washington', 0.9996832960999092),
#  ('Illinois', 'West Virginia', 0.9915106966876307),
#  ('Illinois', 'Wisconsin', 0.9985324749430728),
#  ('Illinois', 'Wyoming', 0.9971975163128207),
#  ('Illinois', 'Puerto Rico', 0.9905325216805315),
#  ('Indiana', 'Iowa', 0.9994499500603209),
#  ('Indiana', 'Kansas', 0.9993351510731074),
#  ('Indiana', 'Kentucky', 0.9995967008576018),
#  ('Indiana', 'Louisiana', 0.9997523696474574),
#  ('Indiana', 'Maine', 0.9848720304334552),
#  ('Indiana', 'Maryland', 0.9985164320414867),
#  ('Indiana', 'Massachusetts', 0.995760354931611),
#  ('Indiana', 'Michigan', 0.998139062649282),
#  ('Indiana', 'Minnesota', 0.9995647807189553),
#  ('Indiana', 'Mississippi', 0.9993947532277073),
#  ('Indiana', 'Missouri', 0.9991671964351958),
#  ('Indiana', 'Montana', 0.9953019251418063),
#  ('Indiana', 'Nebraska', 0.9992390639765873),
#  ('Indiana', 'Nevada', 0.9988008846507828),
#  ('Indiana', 'New Hampshire', 0.9904730862292432),
#  ('Indiana', 'New Jersey', 0.9981579305093624),
#  ('Indiana', 'New Mexico', 0.9983837001778826),
#  ('Indiana', 'New York', 0.9968903933630583),
#  ('Indiana', 'North Carolina', 0.9992042572670863),
#  ('Indiana', 'North Dakota', 0.9976558602849871),
#  ('Indiana', 'Ohio', 0.998931318282428),
#  ('Indiana', 'Oklahoma', 0.9992257924001627),
#  ('Indiana', 'Oregon', 0.9965814270451754),
#  ('Indiana', 'Pennsylvania', 0.9957868576899602),
#  ('Indiana', 'Rhode Island', 0.9951523066819571),
#  ('Indiana', 'South Carolina', 0.9979359849136205),
#  ('Indiana', 'South Dakota', 0.9982934240606675),
#  ('Indiana', 'Tennessee', 0.999349380324697),
#  ('Indiana', 'Texas', 0.9943048999903892),
#  ('Indiana', 'Utah', 0.9803038960001228),
#  ('Indiana', 'Vermont', 0.9874801989681875),
#  ('Indiana', 'Virginia', 0.9990095580945273),
#  ('Indiana', 'Washington', 0.9984947506742141),
#  ('Indiana', 'West Virginia', 0.991771797907906),
#  ('Indiana', 'Wisconsin', 0.9986001065962722),
#  ('Indiana', 'Wyoming', 0.9984151628223987),
#  ('Indiana', 'Puerto Rico', 0.9905025650105621),
#  ('Iowa', 'Kansas', 0.9991216290098087),
#  ('Iowa', 'Kentucky', 0.9994327175109461),
#  ('Iowa', 'Louisiana', 0.9989904926882963),
#  ('Iowa', 'Maine', 0.988151358435634),
#  ('Iowa', 'Maryland', 0.9972856926156045),
#  ('Iowa', 'Massachusetts', 0.9955824381140918),
#  ('Iowa', 'Michigan', 0.9988789016635252),
#  ('Iowa', 'Minnesota', 0.9989443651699351),
#  ('Iowa', 'Mississippi', 0.9991069443369337),
#  ('Iowa', 'Missouri', 0.9996789177304543),
#  ('Iowa', 'Montana', 0.9974874643979982),
#  ('Iowa', 'Nebraska', 0.9989078667349555),
#  ('Iowa', 'Nevada', 0.997734054417332),
#  ('Iowa', 'New Hampshire', 0.991805203804181),
#  ('Iowa', 'New Jersey', 0.9973436942789278),
#  ('Iowa', 'New Mexico', 0.9995602375225113),
#  ('Iowa', 'New York', 0.9964230053890306),
#  ('Iowa', 'North Carolina', 0.9986909909952574),
#  ('Iowa', 'North Dakota', 0.9971329323004625),
#  ('Iowa', 'Ohio', 0.9994885564926562),
#  ('Iowa', 'Oklahoma', 0.998835380164861),
#  ('Iowa', 'Oregon', 0.9971551199224425),
#  ('Iowa', 'Pennsylvania', 0.9972468750930386),
#  ('Iowa', 'Rhode Island', 0.9957009134187905),
#  ('Iowa', 'South Carolina', 0.998911180096862),
#  ('Iowa', 'South Dakota', 0.9991186839635364),
#  ('Iowa', 'Tennessee', 0.999077918912391),
#  ('Iowa', 'Texas', 0.9910001050173045),
#  ('Iowa', 'Utah', 0.9763754757000888),
#  ('Iowa', 'Vermont', 0.9902855739854707),
#  ('Iowa', 'Virginia', 0.9980243424134037),
#  ('Iowa', 'Washington', 0.9975163139479514),
#  ('Iowa', 'West Virginia', 0.9944183942345927),
#  ('Iowa', 'Wisconsin', 0.9991576837955524),
#  ('Iowa', 'Wyoming', 0.9990467893796973),
#  ('Iowa', 'Puerto Rico', 0.9928080162345417),
#  ('Kansas', 'Kentucky', 0.9981697941051915),
#  ('Kansas', 'Louisiana', 0.9996870260770974),
#  ('Kansas', 'Maine', 0.9809697161049807),
#  ('Kansas', 'Maryland', 0.9960455889799169),
#  ('Kansas', 'Massachusetts', 0.9924367419203821),
#  ('Kansas', 'Michigan', 0.9963932409745906),
#  ('Kentucky', 'Utah', 0.974515221628784),
#  ('Kentucky', 'Vermont', 0.9910449708373749),
#  ('Kentucky', 'Virginia', 0.9994668412998167),
#  ('Kentucky', 'Washington', 0.9986632660755512),
#  ('Kentucky', 'West Virginia', 0.9945582653545664),
#  ('Kentucky', 'Wisconsin', 0.9995702437698902),
#  ('Kentucky', 'Wyoming', 0.9978657987636836),
#  ('Kentucky', 'Puerto Rico', 0.9929770307733179),
#  ('Louisiana', 'Maine', 0.9816212143985562),
#  ('Louisiana', 'Maryland', 0.9976722859027727),
#  ('Louisiana', 'Massachusetts', 0.9943796952551643),
#  ('Louisiana', 'Michigan', 0.9969278081398834),
#  ('Louisiana', 'Minnesota', 0.9992092644284056),
#  ('Louisiana', 'Mississippi', 0.9991187654133629),
#  ('Louisiana', 'Missouri', 0.9985925028877649),
#  ('Louisiana', 'Montana', 0.9938922714319668),
#  ('Louisiana', 'Nebraska', 0.9997401848550632),
#  ('Louisiana', 'Nevada', 0.9982528226832137),
#  ('Louisiana', 'New Hampshire', 0.9877927947210304),
#  ('Louisiana', 'New Jersey', 0.9968522830720818),
#  ('Louisiana', 'New Mexico', 0.9982251557989511),
#  ('Louisiana', 'New York', 0.9959137870404778),
#  ('Louisiana', 'North Carolina', 0.9982565639300807),
#  ('Louisiana', 'North Dakota', 0.9984523029214418),
#  ('Louisiana', 'Ohio', 0.998040060194924),
#  ('Louisiana', 'Oklahoma', 0.9997047069226456),
#  ('Louisiana', 'Oregon', 0.9953546150343964),
#  ('Louisiana', 'Pennsylvania', 0.9941139848475765),
#  ('Louisiana', 'Rhode Island', 0.9935526137965776),
#  ('Louisiana', 'South Carolina', 0.996606487513666),
#  ('Louisiana', 'South Dakota', 0.9986027595431788),
#  ('Louisiana', 'Tennessee', 0.9985932313820378),
#  ('Louisiana', 'Texas', 0.9958400805794516),
#  ('Louisiana', 'Utah', 0.9838216113712929),
#  ('Louisiana', 'Vermont', 0.984588141496599),
#  ('Louisiana', 'Virginia', 0.9981754790249748),
#  ('Louisiana', 'Washington', 0.9981393983198455),
#  ('Louisiana', 'West Virginia', 0.9892003595706633),
#  ('Louisiana', 'Wisconsin', 0.9974536817898002),
#  ('Louisiana', 'Wyoming', 0.9986314852554363),
#  ('Louisiana', 'Puerto Rico', 0.987991611549505),
#  ('Maine', 'Maryland', 0.9873510070325944),
#  ('Maine', 'Massachusetts', 0.9926410714449088),
#  ('Maine', 'Michigan', 0.9930386175283759),
#  ('Maine', 'Minnesota', 0.9867978062573067),
#  ('Maine', 'Mississippi', 0.9826050442002251),
#  ('Maine', 'Missouri', 0.9900892349886329),
#  ('Maine', 'Montana', 0.9950797784189429),
#  ('Maine', 'Nebraska', 0.9807680334891264),
#  ('Maine', 'Nevada', 0.9859249702382114),
#  ('Maine', 'New Hampshire', 0.997969532321237),
#  ('Maine', 'New Jersey', 0.9897353860533149),
#  ('Maine', 'New Mexico', 0.9868574587373659),
#  ('Maine', 'New York', 0.990254907202291),
#  ('Maine', 'North Carolina', 0.9886118707054703),
#  ('Maine', 'North Dakota', 0.979932627533783),
#  ('Maine', 'Ohio', 0.9916243477190655),
#  ('Maine', 'Oklahoma', 0.9801896937575713),
#  ('Maine', 'Oregon', 0.9933958259561759),
#  ('Maine', 'Pennsylvania', 0.9963731035508068),
#  ('Maine', 'Rhode Island', 0.9945200262122232),
#  ('Maine', 'South Carolina', 0.9933916596859006),
#  ('Maine', 'South Dakota', 0.9844564764484001),
#  ('Maine', 'Tennessee', 0.9892459234852335),
#  ('Maine', 'Texas', 0.9618794457018575),
#  ('Maine', 'Utah', 0.9321725437407272),
#  ('Maine', 'Vermont', 0.9990850115556802),
#  ('Maine', 'Virginia', 0.9876347367733106),
#  ('Maine', 'Washington', 0.9863993915800215),
#  ('Maine', 'West Virginia', 0.997968860149472),
#  ('Maine', 'Wisconsin', 0.9925102634553025),
#  ('Maine', 'Wyoming', 0.985190565845355),
#  ('Maine', 'Puerto Rico', 0.9948740939582836),
#  ('Maryland', 'Massachusetts', 0.9983570022891588),
#  ('Maryland', 'Michigan', 0.9978204162683507),
#  ('Maryland', 'Minnesota', 0.9993770241403439),
#  ('Maryland', 'Mississippi', 0.9964884061178743),
#  ('Maryland', 'Missouri', 0.9981139361029177),
#  ('Maryland', 'Montana', 0.9940030792998505),
#  ('Maryland', 'Nebraska', 0.9963462730496242),
#  ('Maryland', 'Nevada', 0.9993951535423996),
#  ('Maryland', 'New Hampshire', 0.9937827129518267),
#  ('Maryland', 'New Jersey', 0.9997154777684526),
#  ('Maryland', 'New Mexico', 0.9949382033283198),
#  ('Maryland', 'New York', 0.9986976247254341),
#  ('Maryland', 'North Carolina', 0.9993785695465175),
#  ('Maryland', 'North Dakota', 0.9954818653693921),
#  ('Maryland', 'Ohio', 0.9983229898150598),
#  ('Maryland', 'Oklahoma', 0.996189749000789),
#  ('Maryland', 'Oregon', 0.9977253596445287),
#  ('Maryland', 'Pennsylvania', 0.996425285339215),
#  ('Maryland', 'Rhode Island', 0.9970245805941185),
#  ('Maryland', 'South Carolina', 0.997449703052692),
#  ('Maryland', 'South Dakota', 0.995018793460351),
#  ('Maryland', 'Tennessee', 0.9993673131011787),
#  ('Maryland', 'Texas', 0.9919451235165587),
#  ('Maryland', 'Utah', 0.9732000133703805),
#  ('Maryland', 'Vermont', 0.9892853837737436),
#  ('Maryland', 'Virginia', 0.9998439743657199),
#  ('Maryland', 'Washington', 0.9993955506456402),
#  ('Maryland', 'West Virginia', 0.9917555714279817),
#  ('Maryland', 'Wisconsin', 0.9983339518944312),
#  ('Maryland', 'Wyoming', 0.995717110509121),
#  ('Maryland', 'Puerto Rico', 0.9902262160016363),
#  ('Massachusetts', 'Michigan', 0.9981129244490425),
#  ('Massachusetts', 'Minnesota', 0.9974466130547648),
#  ('Massachusetts', 'Mississippi', 0.992660493944092),
#  ('Massachusetts', 'Missouri', 0.9973989592702872),
#  ('Massachusetts', 'Montana', 0.9959071661430005),
#  ('Massachusetts', 'Nebraska', 0.9929564132872286),
#  ('Massachusetts', 'Nevada', 0.9979194346366028),
#  ('Massachusetts', 'New Hampshire', 0.9971297575966821),
#  ('Massachusetts', 'New Jersey', 0.9984854770853037),
#  ('Massachusetts', 'New Mexico', 0.9936277088455605),
#  ('Massachusetts', 'New York', 0.9997166267434043),
#  ('Massachusetts', 'North Carolina', 0.9977490983059646),
#  ('Massachusetts', 'North Dakota', 0.9938556350045683),
#  ('Massachusetts', 'Ohio', 0.9978693171791623),
#  ('Massachusetts', 'Oklahoma', 0.9925735056549541),
#  ('Massachusetts', 'Oregon', 0.9994110461020709),
#  ('Massachusetts', 'Pennsylvania', 0.998378405881325),
#  ('Massachusetts', 'Rhode Island', 0.9994338985069927),
#  ('Massachusetts', 'South Carolina', 0.997752987693142),
#  ('Massachusetts', 'South Dakota', 0.9930088405457491),
#  ('Massachusetts', 'Tennessee', 0.9982222435075995),
#  ('Massachusetts', 'Texas', 0.9846382457076954),
#  ('Massachusetts', 'Utah', 0.961752804480407),
#  ('Massachusetts', 'Vermont', 0.9942210174875025),
#  ('Massachusetts', 'Virginia', 0.9983154817476154),
#  ('Massachusetts', 'Washington', 0.9984758505303305),
#  ('Massachusetts', 'West Virginia', 0.9944981250232515),
#  ('Massachusetts', 'Wisconsin', 0.9979952272111406),
#  ('Massachusetts', 'Wyoming', 0.993623573142016),
#  ('Massachusetts', 'Puerto Rico', 0.9937616184335953),
#  ('Michigan', 'Minnesota', 0.9983373088580436),
#  ('Michigan', 'Mississippi', 0.9969214695023656),
#  ('Michigan', 'Missouri', 0.9993041347387678),
#  ('Michigan', 'Montana', 0.9989932343324027),
#  ('Michigan', 'Nebraska', 0.9961404154379876),
#  ('Michigan', 'Nevada', 0.9975017793369636),
#  ('Michigan', 'New Hampshire', 0.9964427804028486),
#  ('Michigan', 'New Jersey', 0.9982802182998635),
#  ('Michigan', 'New Mexico', 0.9979561020346982),
#  ('Michigan', 'New York', 0.998202694854268),
#  ('Michigan', 'North Carolina', 0.998581750475549),
#  ('Michigan', 'North Dakota', 0.9957233415684176),
#  ('Michigan', 'Ohio', 0.9997559199144535),
#  ('Michigan', 'Oklahoma', 0.995868126447223),
#  ('Michigan', 'Oregon', 0.9987693386402072),
#  ('Michigan', 'Pennsylvania', 0.9992710073891479),
#  ('Michigan', 'Rhode Island', 0.998779860838745),
#  ('Michigan', 'South Carolina', 0.9995709204073145),
#  ('Michigan', 'South Dakota', 0.9967453297970414),
#  ('Michigan', 'Tennessee', 0.9990310422728707),
#  ('Michigan', 'Texas', 0.9862513905265824),
#  ('Michigan', 'Utah', 0.9669785963603764),
#  ('Michigan', 'Vermont', 0.9952167712400919),
#  ('Michigan', 'Virginia', 0.9983300209809643),
#  ('Michigan', 'Washington', 0.9976195329171864),
#  ('Michigan', 'West Virginia', 0.9971587138018652),
#  ('Michigan', 'Wisconsin', 0.9998817517286118),
#  ('Michigan', 'Wyoming', 0.9971858278098458),
#  ('Michigan', 'Puerto Rico', 0.9957772585376622),
#  ('Minnesota', 'Mississippi', 0.9980292789850994),
#  ('Minnesota', 'Missouri', 0.9993635526062677),
#  ('Minnesota', 'Montana', 0.995373556269688),
#  ('Minnesota', 'Nebraska', 0.9986167723178121),
#  ('Minnesota', 'Nevada', 0.9993198908692723),
#  ('Minnesota', 'New Hampshire', 0.9923870534988294),
#  ('Minnesota', 'New Jersey', 0.9988884192738847),
#  ('Minnesota', 'New Mexico', 0.9975114086647556),
#  ('Minnesota', 'New York', 0.9981528253293765),
#  ('Minnesota', 'North Carolina', 0.999397849686602),
#  ('Minnesota', 'North Dakota', 0.997539461589985),
#  ('Minnesota', 'Ohio', 0.999178914554003),
#  ('Minnesota', 'Oklahoma', 0.9984426520896987),
#  ('Minnesota', 'Oregon', 0.997769957619779),
#  ('Minnesota', 'Pennsylvania', 0.9967265961445444),
#  ('Minnesota', 'Rhode Island', 0.9964275973750655),
#  ('Minnesota', 'South Carolina', 0.9980850093571768),
#  ('Minnesota', 'South Dakota', 0.9978863864283576),
#  ('Minnesota', 'Tennessee', 0.9997297898823206),
#  ('Minnesota', 'Texas', 0.9933583551608314),
#  ('Minnesota', 'Utah', 0.9772854961855515),
#  ('Minnesota', 'Vermont', 0.988811436625571),
#  ('Minnesota', 'Virginia', 0.9994947523239168),
#  ('Minnesota', 'Washington', 0.9994698907073762),
#  ('Minnesota', 'West Virginia', 0.9920390447404898),
#  ('Minnesota', 'Wisconsin', 0.998859264319513),
#  ('Minnesota', 'Wyoming', 0.9982545809691293),
#  ('Minnesota', 'Puerto Rico', 0.990221457050523),
#  ('Mississippi', 'Missouri', 0.9979892200390753),
#  ('Mississippi', 'Montana', 0.9943328713522892),
#  ('Mississippi', 'Nebraska', 0.9988012579369819),
#  ('Mississippi', 'Nevada', 0.9969976305083746),
#  ('Mississippi', 'New Hampshire', 0.9877234314398879),
#  ('Mississippi', 'New Jersey', 0.9964755144525681),
#  ('Mississippi', 'New Mexico', 0.9983352390570056),
#  ('Mississippi', 'New York', 0.9940467205830452),
#  ('Mississippi', 'North Carolina', 0.9980838793850688),
#  ('Mississippi', 'North Dakota', 0.9959460705317922),
#  ('Mississippi', 'Ohio', 0.9977474863901279),
#  ('Mississippi', 'Oklahoma', 0.9989908292462909),
#  ('Mississippi', 'Oregon', 0.9941586661558955),
#  ('Mississippi', 'Pennsylvania', 0.9939801690543463),
#  ('Mississippi', 'Rhode Island', 0.9924580837338466),
#  ('Mississippi', 'South Carolina', 0.9969810950561234),
#  ('Mississippi', 'South Dakota', 0.9977974378095867),
#  ('Mississippi', 'Tennessee', 0.9979276001367939),
#  ('Mississippi', 'Texas', 0.9937875861694402),
#  ('Mississippi', 'Utah', 0.9817605134569503),
#  ('Mississippi', 'Vermont', 0.9853604636547331),
#  ('Mississippi', 'Virginia', 0.9973502655510456),
#  ('Mississippi', 'Washington', 0.9960728888333933),
#  ('Mississippi', 'West Virginia', 0.9910988023959901),
#  ('Mississippi', 'Wisconsin', 0.9974553708200625),
#  ('Mississippi', 'Wyoming', 0.9976573191797866),
#  ('Mississippi', 'Puerto Rico', 0.9898655855117489),
#  ('Missouri', 'Montana', 0.9978862512289474),
#  ('Missouri', 'Nebraska', 0.9983786448192301),
#  ('Missouri', 'Nevada', 0.9984532737904757),
#  ('Missouri', 'New Hampshire', 0.9936715300159006),
#  ('Missouri', 'New Jersey', 0.9980953684220562),
#  ('Missouri', 'New Mexico', 0.9990018223457524),
#  ('Missouri', 'New York', 0.997947218215931),
#  ('Missouri', 'North Carolina', 0.9990277498115745),
#  ('Missouri', 'North Dakota', 0.9972911925370398),
#  ('Missouri', 'Ohio', 0.9998485509870405),
#  ('Missouri', 'Oklahoma', 0.9981901260408876),
#  ('Missouri', 'Oregon', 0.9985897513477511),
#  ('Missouri', 'Pennsylvania', 0.9983399106783482),
#  ('Missouri', 'Rhode Island', 0.9972473676878971),
#  ('Missouri', 'South Carolina', 0.9993242055803944),
#  ('Missouri', 'South Dakota', 0.9987729935821735),
#  ('Missouri', 'Tennessee', 0.9995760741558224),
#  ('Missouri', 'Texas', 0.9900941319131871),
#  ('Missouri', 'Utah', 0.9735791854465883),
#  ('Missouri', 'Vermont', 0.9918602935242821),
#  ('Missouri', 'Virginia', 0.9986313411239806),
#  ('Missouri', 'Washington', 0.9985813639901727),
#  ('Missouri', 'West Virginia', 0.9950070589395247),
#  ('Missouri', 'Wisconsin', 0.9995208712526781),
#  ('Missouri', 'Wyoming', 0.9988076566034345),
#  ...]

# %% [markdown]
# __A9.__ _(3 points)_ Next, we would like to investigate which locations are the most or least similar given these different types of demographics. To support these investigations, write a function called `get_min_max_similarity`. The function should take a `similarity_list`, which is the output from the `compute_cosite_similarity()` method you wrote in A8. The function should return two values `min_similarity` and `max_similarity`. These correspond to the entries from the provided `similarity_list` that have the smallest and largest similarity respectively.
#
# For example `min_similarity` and `max_similarity` will have the format `(<location 1>, <location 2>, <cosine similarity>)`.

# %%
# A9:Function(3/3)

def get_min_max_similarity(similarity_list):
    #---Your code starts here
    min_s = min(similarity_list, key=lambda x: x[2])
    max_s = max(similarity_list, key=lambda x: x[2])
    min_similarity = (min_s[0], min_s[1], min_s[2])
    max_similarity = (max_s[0], max_s[1], max_s[2])
    #---Your code ends here
    return min_similarity, max_similarity

# %% [markdown]
# To test this function, let's apply it to compare states in terms of both race and age similarity.

# %%
# A9:SanityCheck

min_race_similarity, max_race_similarity = get_min_max_similarity(race_similarity)
print("The locations with least similar race demographics: {}".format(min_race_similarity))
print("The locations with most similar race demographics: {}".format(max_race_similarity))
# Out:
# The locations with least similar race demographics: ('West Virginia', 'Puerto Rico', 0.01950610252950971)
# The locations with most similar race demographics: ('Maine', 'Vermont', 0.9999496582673306)

# %%
# A9:SanityCheck

min_age_similarity, max_age_similarity = get_min_max_similarity(age_similarity)
print("The locations with least similar age demographics: {}".format(min_age_similarity))
print("The locations with most similar age demographics: {}".format(max_age_similarity))
# Out:
# The locations with least similar age demographics: ('Maine', 'Utah', 0.9321725437407272)
# The locations with most similar age demographics: ('Nebraska', 'Oklahoma', 0.9999533208314442)
